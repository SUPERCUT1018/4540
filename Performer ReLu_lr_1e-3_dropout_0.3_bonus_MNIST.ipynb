# %%
# https://github.com/lucidrains/vit-pytorch/blob/main/vit_pytorch/vit.py

import torch
from torch import nn

from einops import rearrange, repeat
from einops.layers.torch import Rearrange
# helpers

def pair(t):
    return t if isinstance(t, tuple) else (t, t)

# classes

class PreNorm(nn.Module):
    def __init__(self, dim, fn):
        super().__init__()
        self.norm = nn.LayerNorm(dim)
        self.fn = fn
    def forward(self, x, **kwargs):
        return self.fn(self.norm(x), **kwargs)

class FeedForward(nn.Module):
    def __init__(self, dim, hidden_dim, dropout = 0.):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, dim),
            nn.Dropout(dropout)
        )
    def forward(self, x):
        return self.net(x)

class Attention(nn.Module):
    def __init__(self, dim, heads=8, dim_head=64, dropout=0.):
        super().__init__()
        inner_dim = dim_head * heads
        project_out = not (heads == 1 and dim_head == dim)

        self.heads = heads
        self.scale = dim_head ** -0.5  # Scaling factor for stability

        # Linear projections for Q, K, V
        self.to_qkv = nn.Linear(dim, inner_dim * 3, bias=False)

        # Learnable kernel function fθ
        self.learnable_kernel = nn.Sequential(
            nn.Linear(dim_head, dim_head),
            nn.GELU(),
            nn.Linear(dim_head, dim_head)
        )

        # Output projection
        self.to_out = nn.Sequential(
            nn.Linear(inner_dim, dim),
            nn.Dropout(dropout)
        ) if project_out else nn.Identity()

    def forward(self, x):
        # Compute Q, K, V
        qkv = self.to_qkv(x).chunk(3, dim=-1)
        q, k, v = map(lambda t: rearrange(t, 'b n (h d) -> b h n d', h=self.heads), qkv)

        # Apply learnable kernel function fθ
        q = self.learnable_kernel(q)
        k = self.learnable_kernel(k)

        # Compute attention using kernelized linear attention
        # Step 1: Compute Key-Value projection
        kv = torch.einsum('bhnd,bhmd->bhnm', k, v)

        # Step 2: Compute Query and projected KV
        out = torch.einsum('bhnd,bhnm->bhmd', q, kv)

        # Reshape and project back
        out = rearrange(out, 'b h n d -> b n (h d)')
        return self.to_out(out)

class Transformer(nn.Module):
    def __init__(self, dim, depth, heads, dim_head, mlp_dim, dropout=0.):
        super().__init__()
        self.layers = nn.ModuleList([])
        for _ in range(depth):
            self.layers.append(nn.ModuleList([
                PreNorm(dim, Attention(dim, heads=heads, dim_head=dim_head, dropout=dropout)),  # 调用改造后的 Attention
                PreNorm(dim, FeedForward(dim, mlp_dim, dropout=dropout))
            ]))

    def forward(self, x):
        for attn, ff in self.layers:
            x = attn(x) + x  # Add residual connection
            x = ff(x) + x    # Add residual connection
        return x


class ViTPR(nn.Module):
    def __init__(self, *, image_size, patch_size, num_classes, dim, depth, heads, mlp_dim, pool='cls', channels=3, dim_head=64, dropout=0., emb_dropout=0.):
        super().__init__()
        image_height, image_width = pair(image_size)
        patch_height, patch_width = pair(patch_size)

        assert image_height % patch_height == 0 and image_width % patch_width == 0, 'Image dimensions must be divisible by the patch size.'

        num_patches = (image_height // patch_height) * (image_width // patch_width)
        patch_dim = channels * patch_height * patch_width
        assert pool in {'cls', 'mean'}, 'pool type must be either cls (cls token) or mean (mean pooling)'

        # Patch embedding
        self.to_patch_embedding = nn.Sequential(
            Rearrange('b c (h p1) (w p2) -> b (h w) (p1 p2 c)', p1=patch_height, p2=patch_width),
            nn.Linear(patch_dim, dim),
        )

        # Positional embedding
        self.pos_embedding = nn.Parameter(torch.randn(1, num_patches + 1, dim))
        self.cls_token = nn.Parameter(torch.randn(1, 1, dim))
        self.dropout = nn.Dropout(emb_dropout)

        # Transformer with Performer-ReLU Attention
        self.transformer = Transformer(dim, depth, heads, dim_head, mlp_dim, dropout)

        self.pool = pool
        self.to_latent = nn.Identity()

        # Classification head
        self.mlp_head = nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, num_classes)
        )

    def forward(self, img):
        x = self.to_patch_embedding(img)  # Convert image to patches
        b, n, _ = x.shape

        # Add CLS token
        cls_tokens = repeat(self.cls_token, '() n d -> b n d', b=b)
        x = torch.cat((cls_tokens, x), dim=1)
        x += self.pos_embedding[:, :(n + 1)]
        x = self.dropout(x)

        # Pass through Transformer
        x = self.transformer(x)

        # Pooling
        x = x.mean(dim=1) if self.pool == 'mean' else x[:, 0]

        x = self.to_latent(x)
        return self.mlp_head(x)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import time
import matplotlib.pyplot as plt
import os
import csv
import torch.nn.functional as F

# 超参数
lr = 1e-3
batch_size = 64
num_epochs = 20  # MNIST 训练收敛快，可减少 epoch
patch_size = 7   # 28x28 的图像中，7x7 的 patch
image_size = 28  # MNIST 图像为 28x28
num_classes = 10
dim = 128
depth = 6
heads = 8
mlp_dim = 512
dropout = 0.3
emb_dropout = 0.3
channels = 1     # MNIST 图像为单通道
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 数据集
print("==> Preparing MNIST dataset...")
transform_train = transforms.Compose([
    transforms.RandomCrop(28, padding=4),
    transforms.Resize(image_size),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),  # MNIST 单通道图像归一化
])

transform_test = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,)),
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)

test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform_test)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

# 初始化 ViTPR 模型
print("==> Building Vision Transformer model...")
net = ViTPR(
    image_size=image_size,
    patch_size=patch_size,
    num_classes=num_classes,
    dim=dim,
    depth=depth,
    heads=heads,
    mlp_dim=mlp_dim,
    dropout=dropout,
    emb_dropout=emb_dropout,
    channels=channels  # 单通道
).to(device)


# 定义损失函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(net.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)
# 定义训练函数
def train(epoch):
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    start_time = time.time()

    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)

        # 前向传播
        outputs = net(inputs)
        loss = criterion(outputs, targets)

        # 反向传播和优化
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()

        print(f"Train Epoch [{epoch+1}/{num_epochs}] Batch [{batch_idx+1}/{len(train_loader)}] "
              f"Loss: {loss.item():.4f} | Acc: {100.*correct/total:.2f}%")

    epoch_time = time.time() - start_time
    print(f"Epoch {epoch+1} completed in {epoch_time:.2f}s.")
    return epoch_time, 100. * correct / total

def test(epoch):
    net.eval()
    test_loss = 0
    correct = 0
    total = 0
    start_time = time.time()

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(test_loader):
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = outputs.max(1)
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()

    inference_time = time.time() - start_time
    acc = 100. * correct / total
    print(f"Test Epoch [{epoch+1}/{num_epochs}] "
          f"Loss: {test_loss/len(test_loader):.4f} | Acc: {acc:.2f}% | Inference Time: {inference_time:.2f}s")
    return acc, inference_time
# Out:
# ==> Preparing MNIST dataset...
# ==> Building Vision Transformer model...

# %%
# 保存模型的最佳状态
checkpoint_path = "./Performer ReLu_lr_1e-3_dropout_0.3_bonus_MNIST_checkpoint.pth"
if os.path.exists(checkpoint_path):
    print(f"Loading checkpoint from {checkpoint_path}...")
    checkpoint = torch.load(checkpoint_path)
    net.load_state_dict(checkpoint['model'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    scheduler.load_state_dict(checkpoint['scheduler'])
    best_acc = checkpoint['acc']
    start_epoch = checkpoint['epoch'] + 1
else:
    print("No checkpoint found. Starting from scratch.")
    start_epoch = 0
    best_acc = 0
# 创建或打开 CSV 文件
csv_file = "Performer ReLu_lr_1e-3_dropout_0.3_bonus_MNIST.csv"
write_header = not os.path.exists(csv_file)

with open(csv_file, "a", newline="") as f:
    writer = csv.writer(f)
    if write_header:
        writer.writerow(["Epoch", "Train Time (s)", "Inference Time (s)", "Accuracy (%)"])

    # 开始训练
    train_times = []
    inference_times = []
    accuracies = []

    for epoch in range(start_epoch, num_epochs):
        print(f"Epoch {epoch+1}/{num_epochs}")

        train_time, train_acc = train(epoch)
        train_times.append(train_time)

        acc, inference_time = test(epoch)
        accuracies.append(acc)
        inference_times.append(inference_time)

        scheduler.step()

        if acc > best_acc:
            print("Saving best model...")
            state = {
                'model': net.state_dict(),
                'optimizer': optimizer.state_dict(),
                'scheduler': scheduler.state_dict(),
                'acc': acc,
                'epoch': epoch,
            }
            torch.save(state, checkpoint_path)
            best_acc = acc

        writer.writerow([epoch+1, train_time, inference_time, acc])
        f.flush()
        print(f"Epoch {epoch+1} results saved to CSV.")
# Out:
# Loading checkpoint from ./Performer ReLu_lr_1e-3_dropout_0.3_bonus_MNIST_checkpoint.pth...
# Epoch 3/20
# C:\Users\ZBLibra\AppData\Local\Temp\ipykernel_13036\2419452021.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path)
# Train Epoch [3/20] Batch [1/938] Loss: 0.4390 | Acc: 84.38%
# Train Epoch [3/20] Batch [2/938] Loss: 0.5687 | Acc: 83.59%
# Train Epoch [3/20] Batch [3/938] Loss: 0.7931 | Acc: 80.73%
# Train Epoch [3/20] Batch [4/938] Loss: 0.5287 | Acc: 80.08%
# Train Epoch [3/20] Batch [5/938] Loss: 0.5784 | Acc: 80.00%
# Train Epoch [3/20] Batch [6/938] Loss: 0.4201 | Acc: 80.99%
# Train Epoch [3/20] Batch [7/938] Loss: 0.6437 | Acc: 80.13%
# Train Epoch [3/20] Batch [8/938] Loss: 0.6148 | Acc: 80.66%
# Train Epoch [3/20] Batch [9/938] Loss: 0.6676 | Acc: 79.86%
# Train Epoch [3/20] Batch [10/938] Loss: 0.3439 | Acc: 80.47%
# Train Epoch [3/20] Batch [11/938] Loss: 0.4362 | Acc: 81.11%
# Train Epoch [3/20] Batch [12/938] Loss: 0.6057 | Acc: 81.12%
# Train Epoch [3/20] Batch [13/938] Loss: 0.6279 | Acc: 80.29%
# Train Epoch [3/20] Batch [14/938] Loss: 0.3502 | Acc: 80.92%
# Train Epoch [3/20] Batch [15/938] Loss: 0.4309 | Acc: 81.35%
# Train Epoch [3/20] Batch [16/938] Loss: 0.2732 | Acc: 82.03%
# Train Epoch [3/20] Batch [17/938] Loss: 0.4789 | Acc: 81.80%
# Train Epoch [3/20] Batch [18/938] Loss: 0.6481 | Acc: 81.60%
# Train Epoch [3/20] Batch [19/938] Loss: 0.6833 | Acc: 81.17%
# Train Epoch [3/20] Batch [20/938] Loss: 0.5337 | Acc: 81.25%
# Train Epoch [3/20] Batch [21/938] Loss: 0.5711 | Acc: 81.10%
# Train Epoch [3/20] Batch [22/938] Loss: 0.4482 | Acc: 81.39%
# Train Epoch [3/20] Batch [23/938] Loss: 0.4980 | Acc: 81.18%
# Train Epoch [3/20] Batch [24/938] Loss: 0.4659 | Acc: 81.38%
# Train Epoch [3/20] Batch [25/938] Loss: 0.3969 | Acc: 81.56%
# Train Epoch [3/20] Batch [26/938] Loss: 0.4829 | Acc: 81.61%
# Train Epoch [3/20] Batch [27/938] Loss: 0.6592 | Acc: 81.48%
# Train Epoch [3/20] Batch [28/938] Loss: 0.7731 | Acc: 81.36%
# Train Epoch [3/20] Batch [29/938] Loss: 0.6216 | Acc: 81.25%
# Train Epoch [3/20] Batch [30/938] Loss: 0.3689 | Acc: 81.56%
# Train Epoch [3/20] Batch [31/938] Loss: 0.6530 | Acc: 81.40%
# Train Epoch [3/20] Batch [32/938] Loss: 0.4883 | Acc: 81.40%
# Train Epoch [3/20] Batch [33/938] Loss: 0.4160 | Acc: 81.58%
# Train Epoch [3/20] Batch [34/938] Loss: 0.5419 | Acc: 81.62%
# Train Epoch [3/20] Batch [35/938] Loss: 0.3843 | Acc: 81.83%
# Train Epoch [3/20] Batch [36/938] Loss: 0.5416 | Acc: 81.90%
# Train Epoch [3/20] Batch [37/938] Loss: 0.5937 | Acc: 81.88%
# Train Epoch [3/20] Batch [38/938] Loss: 0.6143 | Acc: 81.78%
# Train Epoch [3/20] Batch [39/938] Loss: 0.5768 | Acc: 81.81%
# Train Epoch [3/20] Batch [40/938] Loss: 0.4926 | Acc: 81.80%
# Train Epoch [3/20] Batch [41/938] Loss: 0.5813 | Acc: 81.71%
# Train Epoch [3/20] Batch [42/938] Loss: 0.5556 | Acc: 81.66%
# Train Epoch [3/20] Batch [43/938] Loss: 0.5682 | Acc: 81.54%
# Train Epoch [3/20] Batch [44/938] Loss: 0.5571 | Acc: 81.53%
# Train Epoch [3/20] Batch [45/938] Loss: 0.4834 | Acc: 81.46%
# Train Epoch [3/20] Batch [46/938] Loss: 0.5389 | Acc: 81.25%
# Train Epoch [3/20] Batch [47/938] Loss: 0.6479 | Acc: 81.18%
# Train Epoch [3/20] Batch [48/938] Loss: 0.4514 | Acc: 81.25%
# Train Epoch [3/20] Batch [49/938] Loss: 0.5190 | Acc: 81.25%
# Train Epoch [3/20] Batch [50/938] Loss: 0.5646 | Acc: 81.31%
# Train Epoch [3/20] Batch [51/938] Loss: 0.5802 | Acc: 81.34%
# Train Epoch [3/20] Batch [52/938] Loss: 0.3471 | Acc: 81.52%
# Train Epoch [3/20] Batch [53/938] Loss: 0.7356 | Acc: 81.34%
# Train Epoch [3/20] Batch [54/938] Loss: 0.5030 | Acc: 81.39%
# Train Epoch [3/20] Batch [55/938] Loss: 0.4242 | Acc: 81.34%
# Train Epoch [3/20] Batch [56/938] Loss: 0.6395 | Acc: 81.17%
# Train Epoch [3/20] Batch [57/938] Loss: 0.4355 | Acc: 81.25%
# Train Epoch [3/20] Batch [58/938] Loss: 0.7470 | Acc: 81.09%
# Train Epoch [3/20] Batch [59/938] Loss: 0.5852 | Acc: 81.06%
# Train Epoch [3/20] Batch [60/938] Loss: 0.5542 | Acc: 81.07%
# Train Epoch [3/20] Batch [61/938] Loss: 0.7014 | Acc: 80.94%
# Train Epoch [3/20] Batch [62/938] Loss: 0.4698 | Acc: 80.97%
# Train Epoch [3/20] Batch [63/938] Loss: 0.8610 | Acc: 80.83%
# Train Epoch [3/20] Batch [64/938] Loss: 0.3256 | Acc: 80.93%
# Train Epoch [3/20] Batch [65/938] Loss: 0.5863 | Acc: 80.96%
# Train Epoch [3/20] Batch [66/938] Loss: 0.5793 | Acc: 80.89%
# Train Epoch [3/20] Batch [67/938] Loss: 0.6759 | Acc: 80.83%
# Train Epoch [3/20] Batch [68/938] Loss: 0.7165 | Acc: 80.79%
# Train Epoch [3/20] Batch [69/938] Loss: 0.3776 | Acc: 80.82%
# Train Epoch [3/20] Batch [70/938] Loss: 0.6253 | Acc: 80.80%
# Train Epoch [3/20] Batch [71/938] Loss: 0.5497 | Acc: 80.72%
# Train Epoch [3/20] Batch [72/938] Loss: 0.4517 | Acc: 80.82%
# Train Epoch [3/20] Batch [73/938] Loss: 0.5103 | Acc: 80.78%
# Train Epoch [3/20] Batch [74/938] Loss: 0.3716 | Acc: 80.85%
# Train Epoch [3/20] Batch [75/938] Loss: 0.5120 | Acc: 80.85%
# Train Epoch [3/20] Batch [76/938] Loss: 0.5982 | Acc: 80.80%
# Train Epoch [3/20] Batch [77/938] Loss: 0.4252 | Acc: 80.91%
# Train Epoch [3/20] Batch [78/938] Loss: 0.4939 | Acc: 80.97%
# Train Epoch [3/20] Batch [79/938] Loss: 0.4933 | Acc: 80.95%
# Train Epoch [3/20] Batch [80/938] Loss: 0.7295 | Acc: 80.88%
# Train Epoch [3/20] Batch [81/938] Loss: 0.5090 | Acc: 80.83%
# Train Epoch [3/20] Batch [82/938] Loss: 0.5136 | Acc: 80.81%
# Train Epoch [3/20] Batch [83/938] Loss: 0.5380 | Acc: 80.82%
# Train Epoch [3/20] Batch [84/938] Loss: 0.7018 | Acc: 80.69%
# Train Epoch [3/20] Batch [85/938] Loss: 0.4033 | Acc: 80.72%
# Train Epoch [3/20] Batch [86/938] Loss: 0.5273 | Acc: 80.69%
# Train Epoch [3/20] Batch [87/938] Loss: 0.5012 | Acc: 80.66%
# Train Epoch [3/20] Batch [88/938] Loss: 0.4362 | Acc: 80.72%
# Train Epoch [3/20] Batch [89/938] Loss: 0.6999 | Acc: 80.64%
# Train Epoch [3/20] Batch [90/938] Loss: 0.5640 | Acc: 80.62%
# Train Epoch [3/20] Batch [91/938] Loss: 0.7263 | Acc: 80.58%
# Train Epoch [3/20] Batch [92/938] Loss: 0.7148 | Acc: 80.50%
# Train Epoch [3/20] Batch [93/938] Loss: 0.6025 | Acc: 80.53%
# Train Epoch [3/20] Batch [94/938] Loss: 0.5000 | Acc: 80.54%
# Train Epoch [3/20] Batch [95/938] Loss: 0.5164 | Acc: 80.54%
# Train Epoch [3/20] Batch [96/938] Loss: 0.4869 | Acc: 80.50%
# Train Epoch [3/20] Batch [97/938] Loss: 0.4473 | Acc: 80.53%
# Train Epoch [3/20] Batch [98/938] Loss: 0.2761 | Acc: 80.66%
# Train Epoch [3/20] Batch [99/938] Loss: 0.7072 | Acc: 80.63%
# Train Epoch [3/20] Batch [100/938] Loss: 0.6087 | Acc: 80.61%
# Train Epoch [3/20] Batch [101/938] Loss: 0.4950 | Acc: 80.58%
# Train Epoch [3/20] Batch [102/938] Loss: 0.3957 | Acc: 80.65%
# Train Epoch [3/20] Batch [103/938] Loss: 0.9231 | Acc: 80.64%
# Train Epoch [3/20] Batch [104/938] Loss: 0.4322 | Acc: 80.66%
# Train Epoch [3/20] Batch [105/938] Loss: 0.6320 | Acc: 80.64%
# Train Epoch [3/20] Batch [106/938] Loss: 0.4911 | Acc: 80.63%
# Train Epoch [3/20] Batch [107/938] Loss: 0.5814 | Acc: 80.61%
# Train Epoch [3/20] Batch [108/938] Loss: 0.5991 | Acc: 80.58%
# Train Epoch [3/20] Batch [109/938] Loss: 0.5461 | Acc: 80.62%
# Train Epoch [3/20] Batch [110/938] Loss: 0.5588 | Acc: 80.61%
# Train Epoch [3/20] Batch [111/938] Loss: 0.7487 | Acc: 80.60%
# Train Epoch [3/20] Batch [112/938] Loss: 0.4674 | Acc: 80.68%
# Train Epoch [3/20] Batch [113/938] Loss: 0.5799 | Acc: 80.74%
# Train Epoch [3/20] Batch [114/938] Loss: 0.5132 | Acc: 80.77%
# Train Epoch [3/20] Batch [115/938] Loss: 0.5461 | Acc: 80.79%
# Train Epoch [3/20] Batch [116/938] Loss: 0.3819 | Acc: 80.83%
# Train Epoch [3/20] Batch [117/938] Loss: 0.3085 | Acc: 80.90%
# Train Epoch [3/20] Batch [118/938] Loss: 0.4388 | Acc: 80.95%
# Train Epoch [3/20] Batch [119/938] Loss: 0.4607 | Acc: 81.01%
# Train Epoch [3/20] Batch [120/938] Loss: 0.6660 | Acc: 81.04%
# Train Epoch [3/20] Batch [121/938] Loss: 0.3764 | Acc: 81.08%
# Train Epoch [3/20] Batch [122/938] Loss: 0.3996 | Acc: 81.12%
# Train Epoch [3/20] Batch [123/938] Loss: 0.5643 | Acc: 81.14%
# Train Epoch [3/20] Batch [124/938] Loss: 0.4026 | Acc: 81.15%
# Train Epoch [3/20] Batch [125/938] Loss: 0.4226 | Acc: 81.14%
# Train Epoch [3/20] Batch [126/938] Loss: 0.4044 | Acc: 81.18%
# Train Epoch [3/20] Batch [127/938] Loss: 0.3772 | Acc: 81.23%
# Train Epoch [3/20] Batch [128/938] Loss: 0.4371 | Acc: 81.25%
# Train Epoch [3/20] Batch [129/938] Loss: 0.5318 | Acc: 81.27%
# Train Epoch [3/20] Batch [130/938] Loss: 0.5252 | Acc: 81.30%
# Train Epoch [3/20] Batch [131/938] Loss: 0.5332 | Acc: 81.27%
# Train Epoch [3/20] Batch [132/938] Loss: 0.4944 | Acc: 81.25%
# Train Epoch [3/20] Batch [133/938] Loss: 0.5148 | Acc: 81.26%
# Train Epoch [3/20] Batch [134/938] Loss: 0.5083 | Acc: 81.25%
# Train Epoch [3/20] Batch [135/938] Loss: 0.4128 | Acc: 81.25%
# Train Epoch [3/20] Batch [136/938] Loss: 0.6534 | Acc: 81.25%
# Train Epoch [3/20] Batch [137/938] Loss: 0.3786 | Acc: 81.32%
# Train Epoch [3/20] Batch [138/938] Loss: 0.6373 | Acc: 81.26%
# Train Epoch [3/20] Batch [139/938] Loss: 0.3370 | Acc: 81.31%
# Train Epoch [3/20] Batch [140/938] Loss: 0.5190 | Acc: 81.29%
# Train Epoch [3/20] Batch [141/938] Loss: 0.3376 | Acc: 81.35%
# Train Epoch [3/20] Batch [142/938] Loss: 0.4587 | Acc: 81.36%
# Train Epoch [3/20] Batch [143/938] Loss: 0.5674 | Acc: 81.32%
# Train Epoch [3/20] Batch [144/938] Loss: 0.5220 | Acc: 81.34%
# Train Epoch [3/20] Batch [145/938] Loss: 0.6548 | Acc: 81.29%
# Train Epoch [3/20] Batch [146/938] Loss: 0.4781 | Acc: 81.30%
# Train Epoch [3/20] Batch [147/938] Loss: 0.5955 | Acc: 81.26%
# Train Epoch [3/20] Batch [148/938] Loss: 0.4821 | Acc: 81.27%
# Train Epoch [3/20] Batch [149/938] Loss: 0.9299 | Acc: 81.18%
# Train Epoch [3/20] Batch [150/938] Loss: 0.3939 | Acc: 81.18%
# Train Epoch [3/20] Batch [151/938] Loss: 0.7056 | Acc: 81.17%
# Train Epoch [3/20] Batch [152/938] Loss: 0.3479 | Acc: 81.22%
# Train Epoch [3/20] Batch [153/938] Loss: 0.4599 | Acc: 81.26%
# Train Epoch [3/20] Batch [154/938] Loss: 0.3437 | Acc: 81.32%
# Train Epoch [3/20] Batch [155/938] Loss: 0.6768 | Acc: 81.29%
# Train Epoch [3/20] Batch [156/938] Loss: 0.9108 | Acc: 81.25%
# Train Epoch [3/20] Batch [157/938] Loss: 0.3127 | Acc: 81.29%
# Train Epoch [3/20] Batch [158/938] Loss: 0.3707 | Acc: 81.33%
# Train Epoch [3/20] Batch [159/938] Loss: 0.5860 | Acc: 81.30%
# Train Epoch [3/20] Batch [160/938] Loss: 0.5250 | Acc: 81.31%
# Train Epoch [3/20] Batch [161/938] Loss: 0.4895 | Acc: 81.33%
# Train Epoch [3/20] Batch [162/938] Loss: 0.4051 | Acc: 81.35%
# Train Epoch [3/20] Batch [163/938] Loss: 0.5763 | Acc: 81.34%
# Train Epoch [3/20] Batch [164/938] Loss: 0.4621 | Acc: 81.33%
# Train Epoch [3/20] Batch [165/938] Loss: 0.4516 | Acc: 81.36%
# Train Epoch [3/20] Batch [166/938] Loss: 0.3890 | Acc: 81.41%
# Train Epoch [3/20] Batch [167/938] Loss: 0.6420 | Acc: 81.41%
# Train Epoch [3/20] Batch [168/938] Loss: 0.6414 | Acc: 81.36%
# Train Epoch [3/20] Batch [169/938] Loss: 0.5085 | Acc: 81.38%
# Train Epoch [3/20] Batch [170/938] Loss: 0.3493 | Acc: 81.44%
# Train Epoch [3/20] Batch [171/938] Loss: 0.4844 | Acc: 81.48%
# Train Epoch [3/20] Batch [172/938] Loss: 0.6068 | Acc: 81.44%
# Train Epoch [3/20] Batch [173/938] Loss: 0.6607 | Acc: 81.41%
# Train Epoch [3/20] Batch [174/938] Loss: 0.5491 | Acc: 81.39%
# Train Epoch [3/20] Batch [175/938] Loss: 0.6063 | Acc: 81.35%
# Train Epoch [3/20] Batch [176/938] Loss: 0.8380 | Acc: 81.27%
# Train Epoch [3/20] Batch [177/938] Loss: 0.4248 | Acc: 81.29%
# Train Epoch [3/20] Batch [178/938] Loss: 0.3716 | Acc: 81.35%
# Train Epoch [3/20] Batch [179/938] Loss: 0.5937 | Acc: 81.34%
# Train Epoch [3/20] Batch [180/938] Loss: 0.4626 | Acc: 81.34%
# Train Epoch [3/20] Batch [181/938] Loss: 0.5060 | Acc: 81.34%
# Train Epoch [3/20] Batch [182/938] Loss: 0.6461 | Acc: 81.35%
# Train Epoch [3/20] Batch [183/938] Loss: 0.5053 | Acc: 81.33%
# Train Epoch [3/20] Batch [184/938] Loss: 0.6775 | Acc: 81.30%
# Train Epoch [3/20] Batch [185/938] Loss: 0.6020 | Acc: 81.29%
# Train Epoch [3/20] Batch [186/938] Loss: 0.8123 | Acc: 81.22%
# Train Epoch [3/20] Batch [187/938] Loss: 0.5168 | Acc: 81.22%
# Train Epoch [3/20] Batch [188/938] Loss: 0.4285 | Acc: 81.24%
# Train Epoch [3/20] Batch [189/938] Loss: 0.6264 | Acc: 81.23%
# Train Epoch [3/20] Batch [190/938] Loss: 0.3634 | Acc: 81.26%
# Train Epoch [3/20] Batch [191/938] Loss: 0.5744 | Acc: 81.25%
# Train Epoch [3/20] Batch [192/938] Loss: 0.4172 | Acc: 81.27%
# Train Epoch [3/20] Batch [193/938] Loss: 0.4525 | Acc: 81.28%
# Train Epoch [3/20] Batch [194/938] Loss: 0.4306 | Acc: 81.28%
# Train Epoch [3/20] Batch [195/938] Loss: 0.4269 | Acc: 81.28%
# Train Epoch [3/20] Batch [196/938] Loss: 0.5491 | Acc: 81.29%
# Train Epoch [3/20] Batch [197/938] Loss: 0.3800 | Acc: 81.34%
# Train Epoch [3/20] Batch [198/938] Loss: 0.4288 | Acc: 81.36%
# Train Epoch [3/20] Batch [199/938] Loss: 0.3213 | Acc: 81.38%
# Train Epoch [3/20] Batch [200/938] Loss: 0.4959 | Acc: 81.39%
# Train Epoch [3/20] Batch [201/938] Loss: 0.4279 | Acc: 81.42%
# Train Epoch [3/20] Batch [202/938] Loss: 0.5183 | Acc: 81.43%
# Train Epoch [3/20] Batch [203/938] Loss: 0.3977 | Acc: 81.46%
# Train Epoch [3/20] Batch [204/938] Loss: 0.4158 | Acc: 81.48%
# Train Epoch [3/20] Batch [205/938] Loss: 0.7003 | Acc: 81.45%
# Train Epoch [3/20] Batch [206/938] Loss: 0.5939 | Acc: 81.44%
# Train Epoch [3/20] Batch [207/938] Loss: 0.6433 | Acc: 81.43%
# Train Epoch [3/20] Batch [208/938] Loss: 0.5686 | Acc: 81.40%
# Train Epoch [3/20] Batch [209/938] Loss: 0.3312 | Acc: 81.43%
# Train Epoch [3/20] Batch [210/938] Loss: 0.4149 | Acc: 81.45%
# Train Epoch [3/20] Batch [211/938] Loss: 0.3930 | Acc: 81.48%
# Train Epoch [3/20] Batch [212/938] Loss: 0.5735 | Acc: 81.46%
# Train Epoch [3/20] Batch [213/938] Loss: 0.4747 | Acc: 81.48%
# Train Epoch [3/20] Batch [214/938] Loss: 0.4115 | Acc: 81.48%
# Train Epoch [3/20] Batch [215/938] Loss: 0.6180 | Acc: 81.47%
# Train Epoch [3/20] Batch [216/938] Loss: 0.5119 | Acc: 81.47%
# Train Epoch [3/20] Batch [217/938] Loss: 0.4520 | Acc: 81.49%
# Train Epoch [3/20] Batch [218/938] Loss: 0.5032 | Acc: 81.49%
# Train Epoch [3/20] Batch [219/938] Loss: 0.2818 | Acc: 81.52%
# Train Epoch [3/20] Batch [220/938] Loss: 0.3430 | Acc: 81.54%
# Train Epoch [3/20] Batch [221/938] Loss: 0.2696 | Acc: 81.59%
# Train Epoch [3/20] Batch [222/938] Loss: 0.7490 | Acc: 81.56%
# Train Epoch [3/20] Batch [223/938] Loss: 0.5071 | Acc: 81.54%
# Train Epoch [3/20] Batch [224/938] Loss: 0.2965 | Acc: 81.58%
# Train Epoch [3/20] Batch [225/938] Loss: 0.3109 | Acc: 81.63%
# Train Epoch [3/20] Batch [226/938] Loss: 0.4882 | Acc: 81.60%
# Train Epoch [3/20] Batch [227/938] Loss: 0.4821 | Acc: 81.59%
# Train Epoch [3/20] Batch [228/938] Loss: 0.4567 | Acc: 81.59%
# Train Epoch [3/20] Batch [229/938] Loss: 0.3634 | Acc: 81.64%
# Train Epoch [3/20] Batch [230/938] Loss: 0.5666 | Acc: 81.63%
# Train Epoch [3/20] Batch [231/938] Loss: 0.7910 | Acc: 81.58%
# Train Epoch [3/20] Batch [232/938] Loss: 0.4603 | Acc: 81.61%
# Train Epoch [3/20] Batch [233/938] Loss: 0.6831 | Acc: 81.57%
# Train Epoch [3/20] Batch [234/938] Loss: 0.5971 | Acc: 81.56%
# Train Epoch [3/20] Batch [235/938] Loss: 0.3245 | Acc: 81.58%
# Train Epoch [3/20] Batch [236/938] Loss: 0.4469 | Acc: 81.59%
# Train Epoch [3/20] Batch [237/938] Loss: 0.5269 | Acc: 81.59%
# Train Epoch [3/20] Batch [238/938] Loss: 0.8470 | Acc: 81.55%
# Train Epoch [3/20] Batch [239/938] Loss: 0.4021 | Acc: 81.56%
# Train Epoch [3/20] Batch [240/938] Loss: 0.4440 | Acc: 81.56%
# Train Epoch [3/20] Batch [241/938] Loss: 0.3245 | Acc: 81.59%
# Train Epoch [3/20] Batch [242/938] Loss: 0.5831 | Acc: 81.57%
# Train Epoch [3/20] Batch [243/938] Loss: 0.5978 | Acc: 81.57%
# Train Epoch [3/20] Batch [244/938] Loss: 0.4433 | Acc: 81.56%
# Train Epoch [3/20] Batch [245/938] Loss: 0.7742 | Acc: 81.51%
# Train Epoch [3/20] Batch [246/938] Loss: 0.7379 | Acc: 81.50%
# Train Epoch [3/20] Batch [247/938] Loss: 0.5346 | Acc: 81.50%
# Train Epoch [3/20] Batch [248/938] Loss: 0.4793 | Acc: 81.50%
# Train Epoch [3/20] Batch [249/938] Loss: 0.7088 | Acc: 81.48%
# Train Epoch [3/20] Batch [250/938] Loss: 0.7102 | Acc: 81.45%
# Train Epoch [3/20] Batch [251/938] Loss: 0.6324 | Acc: 81.42%
# Train Epoch [3/20] Batch [252/938] Loss: 0.6771 | Acc: 81.39%
# Train Epoch [3/20] Batch [253/938] Loss: 0.7084 | Acc: 81.35%
# Train Epoch [3/20] Batch [254/938] Loss: 0.4705 | Acc: 81.33%
# Train Epoch [3/20] Batch [255/938] Loss: 0.5358 | Acc: 81.33%
# Train Epoch [3/20] Batch [256/938] Loss: 0.3783 | Acc: 81.36%
# Train Epoch [3/20] Batch [257/938] Loss: 0.5176 | Acc: 81.36%
# Train Epoch [3/20] Batch [258/938] Loss: 0.6372 | Acc: 81.34%
# Train Epoch [3/20] Batch [259/938] Loss: 0.4255 | Acc: 81.38%
# Train Epoch [3/20] Batch [260/938] Loss: 0.5840 | Acc: 81.37%
# Train Epoch [3/20] Batch [261/938] Loss: 0.3416 | Acc: 81.39%
# Train Epoch [3/20] Batch [262/938] Loss: 0.5360 | Acc: 81.38%
# Train Epoch [3/20] Batch [263/938] Loss: 0.3340 | Acc: 81.42%
# Train Epoch [3/20] Batch [264/938] Loss: 0.5867 | Acc: 81.41%
# Train Epoch [3/20] Batch [265/938] Loss: 0.6439 | Acc: 81.40%
# Train Epoch [3/20] Batch [266/938] Loss: 0.6757 | Acc: 81.39%
# Train Epoch [3/20] Batch [267/938] Loss: 0.5113 | Acc: 81.40%
# Train Epoch [3/20] Batch [268/938] Loss: 0.4753 | Acc: 81.40%
# Train Epoch [3/20] Batch [269/938] Loss: 0.5251 | Acc: 81.41%
# Train Epoch [3/20] Batch [270/938] Loss: 0.3973 | Acc: 81.42%
# Train Epoch [3/20] Batch [271/938] Loss: 0.4530 | Acc: 81.43%
# Train Epoch [3/20] Batch [272/938] Loss: 0.6715 | Acc: 81.41%
# Train Epoch [3/20] Batch [273/938] Loss: 0.5669 | Acc: 81.40%
# Train Epoch [3/20] Batch [274/938] Loss: 0.7680 | Acc: 81.34%
# Train Epoch [3/20] Batch [275/938] Loss: 0.6287 | Acc: 81.33%
# Train Epoch [3/20] Batch [276/938] Loss: 0.4056 | Acc: 81.34%
# Train Epoch [3/20] Batch [277/938] Loss: 0.3270 | Acc: 81.38%
# Train Epoch [3/20] Batch [278/938] Loss: 0.4713 | Acc: 81.38%
# Train Epoch [3/20] Batch [279/938] Loss: 0.3634 | Acc: 81.40%
# Train Epoch [3/20] Batch [280/938] Loss: 0.5037 | Acc: 81.38%
# Train Epoch [3/20] Batch [281/938] Loss: 0.3860 | Acc: 81.39%
# Train Epoch [3/20] Batch [282/938] Loss: 0.4454 | Acc: 81.39%
# Train Epoch [3/20] Batch [283/938] Loss: 0.4130 | Acc: 81.40%
# Train Epoch [3/20] Batch [284/938] Loss: 0.5313 | Acc: 81.40%
# Train Epoch [3/20] Batch [285/938] Loss: 0.5359 | Acc: 81.40%
# Train Epoch [3/20] Batch [286/938] Loss: 0.5733 | Acc: 81.38%
# Train Epoch [3/20] Batch [287/938] Loss: 0.5246 | Acc: 81.38%
# Train Epoch [3/20] Batch [288/938] Loss: 0.5100 | Acc: 81.38%
# Train Epoch [3/20] Batch [289/938] Loss: 0.5487 | Acc: 81.40%
# Train Epoch [3/20] Batch [290/938] Loss: 0.6258 | Acc: 81.39%
# Train Epoch [3/20] Batch [291/938] Loss: 0.4785 | Acc: 81.41%
# Train Epoch [3/20] Batch [292/938] Loss: 0.5055 | Acc: 81.42%
# Train Epoch [3/20] Batch [293/938] Loss: 0.3607 | Acc: 81.44%
# Train Epoch [3/20] Batch [294/938] Loss: 0.4956 | Acc: 81.44%
# Train Epoch [3/20] Batch [295/938] Loss: 0.3387 | Acc: 81.47%
# Train Epoch [3/20] Batch [296/938] Loss: 0.3543 | Acc: 81.49%
# Train Epoch [3/20] Batch [297/938] Loss: 0.4232 | Acc: 81.49%
# Train Epoch [3/20] Batch [298/938] Loss: 0.5964 | Acc: 81.48%
# Train Epoch [3/20] Batch [299/938] Loss: 0.6090 | Acc: 81.48%
# Train Epoch [3/20] Batch [300/938] Loss: 0.7848 | Acc: 81.46%
# Train Epoch [3/20] Batch [301/938] Loss: 0.4362 | Acc: 81.46%
# Train Epoch [3/20] Batch [302/938] Loss: 0.6068 | Acc: 81.46%
# Train Epoch [3/20] Batch [303/938] Loss: 0.4453 | Acc: 81.48%
# Train Epoch [3/20] Batch [304/938] Loss: 0.4495 | Acc: 81.49%
# Train Epoch [3/20] Batch [305/938] Loss: 0.5298 | Acc: 81.49%
# Train Epoch [3/20] Batch [306/938] Loss: 0.4653 | Acc: 81.49%
# Train Epoch [3/20] Batch [307/938] Loss: 0.5810 | Acc: 81.48%
# Train Epoch [3/20] Batch [308/938] Loss: 0.6473 | Acc: 81.48%
# Train Epoch [3/20] Batch [309/938] Loss: 0.4093 | Acc: 81.49%
# Train Epoch [3/20] Batch [310/938] Loss: 0.7743 | Acc: 81.47%
# Train Epoch [3/20] Batch [311/938] Loss: 0.6277 | Acc: 81.47%
# Train Epoch [3/20] Batch [312/938] Loss: 0.4534 | Acc: 81.46%
# Train Epoch [3/20] Batch [313/938] Loss: 0.2998 | Acc: 81.48%
# Train Epoch [3/20] Batch [314/938] Loss: 0.5508 | Acc: 81.49%
# Train Epoch [3/20] Batch [315/938] Loss: 0.5200 | Acc: 81.51%
# Train Epoch [3/20] Batch [316/938] Loss: 0.5139 | Acc: 81.52%
# Train Epoch [3/20] Batch [317/938] Loss: 0.5251 | Acc: 81.54%
# Train Epoch [3/20] Batch [318/938] Loss: 0.3834 | Acc: 81.55%
# Train Epoch [3/20] Batch [319/938] Loss: 0.3901 | Acc: 81.57%
# Train Epoch [3/20] Batch [320/938] Loss: 0.6535 | Acc: 81.55%
# Train Epoch [3/20] Batch [321/938] Loss: 0.5286 | Acc: 81.54%
# Train Epoch [3/20] Batch [322/938] Loss: 0.6702 | Acc: 81.54%
# Train Epoch [3/20] Batch [323/938] Loss: 0.7535 | Acc: 81.53%
# Train Epoch [3/20] Batch [324/938] Loss: 0.5308 | Acc: 81.52%
# Train Epoch [3/20] Batch [325/938] Loss: 0.5022 | Acc: 81.52%
# Train Epoch [3/20] Batch [326/938] Loss: 0.4151 | Acc: 81.53%
# Train Epoch [3/20] Batch [327/938] Loss: 0.5611 | Acc: 81.51%
# Train Epoch [3/20] Batch [328/938] Loss: 0.5084 | Acc: 81.52%
# Train Epoch [3/20] Batch [329/938] Loss: 0.4861 | Acc: 81.52%
# Train Epoch [3/20] Batch [330/938] Loss: 0.4345 | Acc: 81.53%
# Train Epoch [3/20] Batch [331/938] Loss: 0.4417 | Acc: 81.55%
# Train Epoch [3/20] Batch [332/938] Loss: 0.6792 | Acc: 81.52%
# Train Epoch [3/20] Batch [333/938] Loss: 0.4650 | Acc: 81.54%
# Train Epoch [3/20] Batch [334/938] Loss: 0.3393 | Acc: 81.56%
# Train Epoch [3/20] Batch [335/938] Loss: 0.5279 | Acc: 81.55%
# Train Epoch [3/20] Batch [336/938] Loss: 0.4330 | Acc: 81.56%
# Train Epoch [3/20] Batch [337/938] Loss: 0.5679 | Acc: 81.56%
# Train Epoch [3/20] Batch [338/938] Loss: 0.5912 | Acc: 81.54%
# Train Epoch [3/20] Batch [339/938] Loss: 0.6488 | Acc: 81.51%
# Train Epoch [3/20] Batch [340/938] Loss: 0.6091 | Acc: 81.48%
# Train Epoch [3/20] Batch [341/938] Loss: 0.5080 | Acc: 81.49%
# Train Epoch [3/20] Batch [342/938] Loss: 0.4768 | Acc: 81.50%
# Train Epoch [3/20] Batch [343/938] Loss: 0.4106 | Acc: 81.51%
# Train Epoch [3/20] Batch [344/938] Loss: 0.5612 | Acc: 81.50%
# Train Epoch [3/20] Batch [345/938] Loss: 0.5012 | Acc: 81.49%
# Train Epoch [3/20] Batch [346/938] Loss: 0.5086 | Acc: 81.48%
# Train Epoch [3/20] Batch [347/938] Loss: 0.3667 | Acc: 81.48%
# Train Epoch [3/20] Batch [348/938] Loss: 0.5899 | Acc: 81.50%
# Train Epoch [3/20] Batch [349/938] Loss: 0.6983 | Acc: 81.47%
# Train Epoch [3/20] Batch [350/938] Loss: 0.3491 | Acc: 81.50%
# Train Epoch [3/20] Batch [351/938] Loss: 0.4731 | Acc: 81.50%
# Train Epoch [3/20] Batch [352/938] Loss: 0.5234 | Acc: 81.51%
# Train Epoch [3/20] Batch [353/938] Loss: 0.6871 | Acc: 81.51%
# Train Epoch [3/20] Batch [354/938] Loss: 0.3626 | Acc: 81.52%
# Train Epoch [3/20] Batch [355/938] Loss: 0.6865 | Acc: 81.51%
# Train Epoch [3/20] Batch [356/938] Loss: 0.4946 | Acc: 81.51%
# Train Epoch [3/20] Batch [357/938] Loss: 0.4845 | Acc: 81.52%
# Train Epoch [3/20] Batch [358/938] Loss: 0.7066 | Acc: 81.51%
# Train Epoch [3/20] Batch [359/938] Loss: 0.3616 | Acc: 81.52%
# Train Epoch [3/20] Batch [360/938] Loss: 0.4939 | Acc: 81.52%
# Train Epoch [3/20] Batch [361/938] Loss: 0.4949 | Acc: 81.52%
# Train Epoch [3/20] Batch [362/938] Loss: 0.4359 | Acc: 81.53%
# Train Epoch [3/20] Batch [363/938] Loss: 0.5781 | Acc: 81.52%
# Train Epoch [3/20] Batch [364/938] Loss: 0.4338 | Acc: 81.53%
# Train Epoch [3/20] Batch [365/938] Loss: 0.5175 | Acc: 81.55%
# Train Epoch [3/20] Batch [366/938] Loss: 0.5387 | Acc: 81.55%
# Train Epoch [3/20] Batch [367/938] Loss: 0.6608 | Acc: 81.54%
# Train Epoch [3/20] Batch [368/938] Loss: 0.4750 | Acc: 81.56%
# Train Epoch [3/20] Batch [369/938] Loss: 0.5133 | Acc: 81.55%
# Train Epoch [3/20] Batch [370/938] Loss: 0.6086 | Acc: 81.54%
# Train Epoch [3/20] Batch [371/938] Loss: 0.8698 | Acc: 81.52%
# Train Epoch [3/20] Batch [372/938] Loss: 0.6793 | Acc: 81.51%
# Train Epoch [3/20] Batch [373/938] Loss: 0.4434 | Acc: 81.51%
# Train Epoch [3/20] Batch [374/938] Loss: 0.4958 | Acc: 81.51%
# Train Epoch [3/20] Batch [375/938] Loss: 0.6312 | Acc: 81.50%
# Train Epoch [3/20] Batch [376/938] Loss: 0.5926 | Acc: 81.50%
# Train Epoch [3/20] Batch [377/938] Loss: 0.7473 | Acc: 81.49%
# Train Epoch [3/20] Batch [378/938] Loss: 0.7257 | Acc: 81.47%
# Train Epoch [3/20] Batch [379/938] Loss: 0.4674 | Acc: 81.48%
# Train Epoch [3/20] Batch [380/938] Loss: 0.4441 | Acc: 81.48%
# Train Epoch [3/20] Batch [381/938] Loss: 0.4610 | Acc: 81.49%
# Train Epoch [3/20] Batch [382/938] Loss: 0.4243 | Acc: 81.48%
# Train Epoch [3/20] Batch [383/938] Loss: 0.4639 | Acc: 81.49%
# Train Epoch [3/20] Batch [384/938] Loss: 0.7093 | Acc: 81.46%
# Train Epoch [3/20] Batch [385/938] Loss: 0.4012 | Acc: 81.48%
# Train Epoch [3/20] Batch [386/938] Loss: 0.7775 | Acc: 81.46%
# Train Epoch [3/20] Batch [387/938] Loss: 0.5171 | Acc: 81.46%
# Train Epoch [3/20] Batch [388/938] Loss: 0.5491 | Acc: 81.46%
# Train Epoch [3/20] Batch [389/938] Loss: 0.4804 | Acc: 81.47%
# Train Epoch [3/20] Batch [390/938] Loss: 0.7612 | Acc: 81.46%
# Train Epoch [3/20] Batch [391/938] Loss: 0.5885 | Acc: 81.47%
# Train Epoch [3/20] Batch [392/938] Loss: 0.4288 | Acc: 81.47%
# Train Epoch [3/20] Batch [393/938] Loss: 0.3238 | Acc: 81.49%
# Train Epoch [3/20] Batch [394/938] Loss: 0.7192 | Acc: 81.47%
# Train Epoch [3/20] Batch [395/938] Loss: 0.5123 | Acc: 81.47%
# Train Epoch [3/20] Batch [396/938] Loss: 0.5243 | Acc: 81.47%
# Train Epoch [3/20] Batch [397/938] Loss: 0.5184 | Acc: 81.47%
# Train Epoch [3/20] Batch [398/938] Loss: 0.3707 | Acc: 81.49%
# Train Epoch [3/20] Batch [399/938] Loss: 0.5295 | Acc: 81.48%
# Train Epoch [3/20] Batch [400/938] Loss: 0.4582 | Acc: 81.49%
# Train Epoch [3/20] Batch [401/938] Loss: 0.5682 | Acc: 81.50%
# Train Epoch [3/20] Batch [402/938] Loss: 0.4302 | Acc: 81.50%
# Train Epoch [3/20] Batch [403/938] Loss: 0.6610 | Acc: 81.49%
# Train Epoch [3/20] Batch [404/938] Loss: 0.5385 | Acc: 81.49%
# Train Epoch [3/20] Batch [405/938] Loss: 0.5440 | Acc: 81.49%
# Train Epoch [3/20] Batch [406/938] Loss: 0.8212 | Acc: 81.49%
# Train Epoch [3/20] Batch [407/938] Loss: 0.5492 | Acc: 81.50%
# Train Epoch [3/20] Batch [408/938] Loss: 0.6336 | Acc: 81.48%
# Train Epoch [3/20] Batch [409/938] Loss: 0.5597 | Acc: 81.48%
# Train Epoch [3/20] Batch [410/938] Loss: 0.5775 | Acc: 81.46%
# Train Epoch [3/20] Batch [411/938] Loss: 0.4277 | Acc: 81.46%
# Train Epoch [3/20] Batch [412/938] Loss: 0.3834 | Acc: 81.46%
# Train Epoch [3/20] Batch [413/938] Loss: 0.3943 | Acc: 81.47%
# Train Epoch [3/20] Batch [414/938] Loss: 0.5526 | Acc: 81.48%
# Train Epoch [3/20] Batch [415/938] Loss: 0.5135 | Acc: 81.47%
# Train Epoch [3/20] Batch [416/938] Loss: 0.4056 | Acc: 81.49%
# Train Epoch [3/20] Batch [417/938] Loss: 0.7106 | Acc: 81.47%
# Train Epoch [3/20] Batch [418/938] Loss: 0.6436 | Acc: 81.46%
# Train Epoch [3/20] Batch [419/938] Loss: 0.2769 | Acc: 81.48%
# Train Epoch [3/20] Batch [420/938] Loss: 0.6050 | Acc: 81.48%
# Train Epoch [3/20] Batch [421/938] Loss: 0.6440 | Acc: 81.47%
# Train Epoch [3/20] Batch [422/938] Loss: 0.4242 | Acc: 81.48%
# Train Epoch [3/20] Batch [423/938] Loss: 0.4242 | Acc: 81.48%
# Train Epoch [3/20] Batch [424/938] Loss: 0.4853 | Acc: 81.49%
# Train Epoch [3/20] Batch [425/938] Loss: 0.4787 | Acc: 81.50%
# Train Epoch [3/20] Batch [426/938] Loss: 0.4959 | Acc: 81.50%
# Train Epoch [3/20] Batch [427/938] Loss: 0.5764 | Acc: 81.50%
# Train Epoch [3/20] Batch [428/938] Loss: 0.4221 | Acc: 81.51%
# Train Epoch [3/20] Batch [429/938] Loss: 0.6247 | Acc: 81.50%
# Train Epoch [3/20] Batch [430/938] Loss: 0.5294 | Acc: 81.51%
# Train Epoch [3/20] Batch [431/938] Loss: 0.2583 | Acc: 81.54%
# Train Epoch [3/20] Batch [432/938] Loss: 0.5720 | Acc: 81.54%
# Train Epoch [3/20] Batch [433/938] Loss: 0.4188 | Acc: 81.55%
# Train Epoch [3/20] Batch [434/938] Loss: 0.5514 | Acc: 81.56%
# Train Epoch [3/20] Batch [435/938] Loss: 0.4592 | Acc: 81.57%
# Train Epoch [3/20] Batch [436/938] Loss: 0.4814 | Acc: 81.57%
# Train Epoch [3/20] Batch [437/938] Loss: 0.4438 | Acc: 81.58%
# Train Epoch [3/20] Batch [438/938] Loss: 0.4525 | Acc: 81.58%
# Train Epoch [3/20] Batch [439/938] Loss: 0.4993 | Acc: 81.58%
# Train Epoch [3/20] Batch [440/938] Loss: 0.6160 | Acc: 81.58%
# Train Epoch [3/20] Batch [441/938] Loss: 0.3767 | Acc: 81.59%
# Train Epoch [3/20] Batch [442/938] Loss: 0.6005 | Acc: 81.58%
# Train Epoch [3/20] Batch [443/938] Loss: 0.4034 | Acc: 81.60%
# Train Epoch [3/20] Batch [444/938] Loss: 0.4239 | Acc: 81.60%
# Train Epoch [3/20] Batch [445/938] Loss: 0.6142 | Acc: 81.58%
# Train Epoch [3/20] Batch [446/938] Loss: 0.7484 | Acc: 81.56%
# Train Epoch [3/20] Batch [447/938] Loss: 0.3474 | Acc: 81.58%
# Train Epoch [3/20] Batch [448/938] Loss: 0.3933 | Acc: 81.59%
# Train Epoch [3/20] Batch [449/938] Loss: 0.5779 | Acc: 81.57%
# Train Epoch [3/20] Batch [450/938] Loss: 0.5344 | Acc: 81.58%
# Train Epoch [3/20] Batch [451/938] Loss: 0.8590 | Acc: 81.57%
# Train Epoch [3/20] Batch [452/938] Loss: 0.7387 | Acc: 81.55%
# Train Epoch [3/20] Batch [453/938] Loss: 0.5600 | Acc: 81.54%
# Train Epoch [3/20] Batch [454/938] Loss: 0.3757 | Acc: 81.56%
# Train Epoch [3/20] Batch [455/938] Loss: 0.3761 | Acc: 81.56%
# Train Epoch [3/20] Batch [456/938] Loss: 0.3443 | Acc: 81.58%
# Train Epoch [3/20] Batch [457/938] Loss: 0.6747 | Acc: 81.58%
# Train Epoch [3/20] Batch [458/938] Loss: 0.4836 | Acc: 81.59%
# Train Epoch [3/20] Batch [459/938] Loss: 0.4273 | Acc: 81.60%
# Train Epoch [3/20] Batch [460/938] Loss: 0.5711 | Acc: 81.59%
# Train Epoch [3/20] Batch [461/938] Loss: 0.4052 | Acc: 81.59%
# Train Epoch [3/20] Batch [462/938] Loss: 0.4581 | Acc: 81.59%
# Train Epoch [3/20] Batch [463/938] Loss: 0.8253 | Acc: 81.59%
# Train Epoch [3/20] Batch [464/938] Loss: 0.6140 | Acc: 81.58%
# Train Epoch [3/20] Batch [465/938] Loss: 0.5622 | Acc: 81.57%
# Train Epoch [3/20] Batch [466/938] Loss: 0.3858 | Acc: 81.59%
# Train Epoch [3/20] Batch [467/938] Loss: 0.4806 | Acc: 81.59%
# Train Epoch [3/20] Batch [468/938] Loss: 0.4712 | Acc: 81.59%
# Train Epoch [3/20] Batch [469/938] Loss: 0.2940 | Acc: 81.62%
# Train Epoch [3/20] Batch [470/938] Loss: 0.3802 | Acc: 81.63%
# Train Epoch [3/20] Batch [471/938] Loss: 0.6704 | Acc: 81.61%
# Train Epoch [3/20] Batch [472/938] Loss: 0.3830 | Acc: 81.63%
# Train Epoch [3/20] Batch [473/938] Loss: 0.5215 | Acc: 81.63%
# Train Epoch [3/20] Batch [474/938] Loss: 0.5445 | Acc: 81.64%
# Train Epoch [3/20] Batch [475/938] Loss: 0.6877 | Acc: 81.63%
# Train Epoch [3/20] Batch [476/938] Loss: 0.5398 | Acc: 81.62%
# Train Epoch [3/20] Batch [477/938] Loss: 0.4114 | Acc: 81.63%
# Train Epoch [3/20] Batch [478/938] Loss: 0.5929 | Acc: 81.62%
# Train Epoch [3/20] Batch [479/938] Loss: 0.5466 | Acc: 81.62%
# Train Epoch [3/20] Batch [480/938] Loss: 0.6597 | Acc: 81.61%
# Train Epoch [3/20] Batch [481/938] Loss: 0.5367 | Acc: 81.61%
# Train Epoch [3/20] Batch [482/938] Loss: 0.5916 | Acc: 81.61%
# Train Epoch [3/20] Batch [483/938] Loss: 0.4298 | Acc: 81.62%
# Train Epoch [3/20] Batch [484/938] Loss: 0.6181 | Acc: 81.61%
# Train Epoch [3/20] Batch [485/938] Loss: 0.7687 | Acc: 81.60%
# Train Epoch [3/20] Batch [486/938] Loss: 0.4541 | Acc: 81.61%
# Train Epoch [3/20] Batch [487/938] Loss: 0.4686 | Acc: 81.62%
# Train Epoch [3/20] Batch [488/938] Loss: 0.3804 | Acc: 81.63%
# Train Epoch [3/20] Batch [489/938] Loss: 0.5295 | Acc: 81.63%
# Train Epoch [3/20] Batch [490/938] Loss: 0.6048 | Acc: 81.63%
# Train Epoch [3/20] Batch [491/938] Loss: 0.3593 | Acc: 81.64%
# Train Epoch [3/20] Batch [492/938] Loss: 0.6006 | Acc: 81.63%
# Train Epoch [3/20] Batch [493/938] Loss: 0.6535 | Acc: 81.62%
# Train Epoch [3/20] Batch [494/938] Loss: 0.4502 | Acc: 81.62%
# Train Epoch [3/20] Batch [495/938] Loss: 0.5727 | Acc: 81.62%
# Train Epoch [3/20] Batch [496/938] Loss: 0.3589 | Acc: 81.62%
# Train Epoch [3/20] Batch [497/938] Loss: 0.4124 | Acc: 81.64%
# Train Epoch [3/20] Batch [498/938] Loss: 0.5780 | Acc: 81.63%
# Train Epoch [3/20] Batch [499/938] Loss: 0.5244 | Acc: 81.63%
# Train Epoch [3/20] Batch [500/938] Loss: 0.6187 | Acc: 81.62%
# Train Epoch [3/20] Batch [501/938] Loss: 0.6447 | Acc: 81.60%
# Train Epoch [3/20] Batch [502/938] Loss: 0.4144 | Acc: 81.61%
# Train Epoch [3/20] Batch [503/938] Loss: 0.6030 | Acc: 81.61%
# Train Epoch [3/20] Batch [504/938] Loss: 0.3707 | Acc: 81.63%
# Train Epoch [3/20] Batch [505/938] Loss: 0.8468 | Acc: 81.62%
# Train Epoch [3/20] Batch [506/938] Loss: 0.6250 | Acc: 81.62%
# Train Epoch [3/20] Batch [507/938] Loss: 0.5036 | Acc: 81.62%
# Train Epoch [3/20] Batch [508/938] Loss: 0.5954 | Acc: 81.61%
# Train Epoch [3/20] Batch [509/938] Loss: 0.3838 | Acc: 81.62%
# Train Epoch [3/20] Batch [510/938] Loss: 0.3076 | Acc: 81.64%
# Train Epoch [3/20] Batch [511/938] Loss: 0.4631 | Acc: 81.65%
# Train Epoch [3/20] Batch [512/938] Loss: 0.5800 | Acc: 81.64%
# Train Epoch [3/20] Batch [513/938] Loss: 0.5831 | Acc: 81.64%
# Train Epoch [3/20] Batch [514/938] Loss: 0.4219 | Acc: 81.64%
# Train Epoch [3/20] Batch [515/938] Loss: 0.4063 | Acc: 81.65%
# Train Epoch [3/20] Batch [516/938] Loss: 0.5495 | Acc: 81.64%
# Train Epoch [3/20] Batch [517/938] Loss: 0.5871 | Acc: 81.63%
# Train Epoch [3/20] Batch [518/938] Loss: 0.5110 | Acc: 81.64%
# Train Epoch [3/20] Batch [519/938] Loss: 0.2947 | Acc: 81.65%
# Train Epoch [3/20] Batch [520/938] Loss: 0.4188 | Acc: 81.66%
# Train Epoch [3/20] Batch [521/938] Loss: 0.6232 | Acc: 81.66%
# Train Epoch [3/20] Batch [522/938] Loss: 0.4461 | Acc: 81.67%
# Train Epoch [3/20] Batch [523/938] Loss: 0.6474 | Acc: 81.66%
# Train Epoch [3/20] Batch [524/938] Loss: 0.5881 | Acc: 81.66%
# Train Epoch [3/20] Batch [525/938] Loss: 0.4176 | Acc: 81.67%
# Train Epoch [3/20] Batch [526/938] Loss: 0.3422 | Acc: 81.67%
# Train Epoch [3/20] Batch [527/938] Loss: 0.4219 | Acc: 81.67%
# Train Epoch [3/20] Batch [528/938] Loss: 0.4794 | Acc: 81.67%
# Train Epoch [3/20] Batch [529/938] Loss: 0.4335 | Acc: 81.69%
# Train Epoch [3/20] Batch [530/938] Loss: 0.6091 | Acc: 81.68%
# Train Epoch [3/20] Batch [531/938] Loss: 0.5616 | Acc: 81.68%
# Train Epoch [3/20] Batch [532/938] Loss: 0.5286 | Acc: 81.68%
# Train Epoch [3/20] Batch [533/938] Loss: 0.4336 | Acc: 81.68%
# Train Epoch [3/20] Batch [534/938] Loss: 0.4342 | Acc: 81.68%
# Train Epoch [3/20] Batch [535/938] Loss: 0.2979 | Acc: 81.69%
# Train Epoch [3/20] Batch [536/938] Loss: 0.3748 | Acc: 81.70%
# Train Epoch [3/20] Batch [537/938] Loss: 0.5119 | Acc: 81.70%
# Train Epoch [3/20] Batch [538/938] Loss: 0.4800 | Acc: 81.71%
# Train Epoch [3/20] Batch [539/938] Loss: 0.5906 | Acc: 81.71%
# Train Epoch [3/20] Batch [540/938] Loss: 0.3683 | Acc: 81.72%
# Train Epoch [3/20] Batch [541/938] Loss: 0.5622 | Acc: 81.73%
# Train Epoch [3/20] Batch [542/938] Loss: 0.6268 | Acc: 81.72%
# Train Epoch [3/20] Batch [543/938] Loss: 0.2242 | Acc: 81.74%
# Train Epoch [3/20] Batch [544/938] Loss: 0.5671 | Acc: 81.73%
# Train Epoch [3/20] Batch [545/938] Loss: 0.3253 | Acc: 81.75%
# Train Epoch [3/20] Batch [546/938] Loss: 0.4425 | Acc: 81.76%
# Train Epoch [3/20] Batch [547/938] Loss: 0.6403 | Acc: 81.75%
# Train Epoch [3/20] Batch [548/938] Loss: 0.7174 | Acc: 81.73%
# Train Epoch [3/20] Batch [549/938] Loss: 0.4303 | Acc: 81.74%
# Train Epoch [3/20] Batch [550/938] Loss: 0.7347 | Acc: 81.71%
# Train Epoch [3/20] Batch [551/938] Loss: 0.3949 | Acc: 81.71%
# Train Epoch [3/20] Batch [552/938] Loss: 0.6030 | Acc: 81.71%
# Train Epoch [3/20] Batch [553/938] Loss: 0.3269 | Acc: 81.72%
# Train Epoch [3/20] Batch [554/938] Loss: 0.4133 | Acc: 81.72%
# Train Epoch [3/20] Batch [555/938] Loss: 0.4494 | Acc: 81.73%
# Train Epoch [3/20] Batch [556/938] Loss: 0.4660 | Acc: 81.73%
# Train Epoch [3/20] Batch [557/938] Loss: 0.6310 | Acc: 81.71%
# Train Epoch [3/20] Batch [558/938] Loss: 0.5264 | Acc: 81.71%
# Train Epoch [3/20] Batch [559/938] Loss: 0.5812 | Acc: 81.70%
# Train Epoch [3/20] Batch [560/938] Loss: 0.5732 | Acc: 81.70%
# Train Epoch [3/20] Batch [561/938] Loss: 0.4596 | Acc: 81.69%
# Train Epoch [3/20] Batch [562/938] Loss: 0.6026 | Acc: 81.69%
# Train Epoch [3/20] Batch [563/938] Loss: 0.5138 | Acc: 81.69%
# Train Epoch [3/20] Batch [564/938] Loss: 0.4723 | Acc: 81.70%
# Train Epoch [3/20] Batch [565/938] Loss: 0.4602 | Acc: 81.69%
# Train Epoch [3/20] Batch [566/938] Loss: 0.4843 | Acc: 81.68%
# Train Epoch [3/20] Batch [567/938] Loss: 0.6074 | Acc: 81.67%
# Train Epoch [3/20] Batch [568/938] Loss: 0.5531 | Acc: 81.67%
# Train Epoch [3/20] Batch [569/938] Loss: 0.4210 | Acc: 81.68%
# Train Epoch [3/20] Batch [570/938] Loss: 0.4369 | Acc: 81.68%
# Train Epoch [3/20] Batch [571/938] Loss: 0.3652 | Acc: 81.69%
# Train Epoch [3/20] Batch [572/938] Loss: 0.6190 | Acc: 81.68%
# Train Epoch [3/20] Batch [573/938] Loss: 0.4009 | Acc: 81.69%
# Train Epoch [3/20] Batch [574/938] Loss: 0.3690 | Acc: 81.70%
# Train Epoch [3/20] Batch [575/938] Loss: 0.5685 | Acc: 81.70%
# Train Epoch [3/20] Batch [576/938] Loss: 0.4466 | Acc: 81.71%
# Train Epoch [3/20] Batch [577/938] Loss: 0.2173 | Acc: 81.73%
# Train Epoch [3/20] Batch [578/938] Loss: 0.4836 | Acc: 81.73%
# Train Epoch [3/20] Batch [579/938] Loss: 0.4173 | Acc: 81.74%
# Train Epoch [3/20] Batch [580/938] Loss: 0.3916 | Acc: 81.74%
# Train Epoch [3/20] Batch [581/938] Loss: 0.5290 | Acc: 81.74%
# Train Epoch [3/20] Batch [582/938] Loss: 0.2890 | Acc: 81.75%
# Train Epoch [3/20] Batch [583/938] Loss: 0.4214 | Acc: 81.76%
# Train Epoch [3/20] Batch [584/938] Loss: 0.4829 | Acc: 81.75%
# Train Epoch [3/20] Batch [585/938] Loss: 0.5298 | Acc: 81.76%
# Train Epoch [3/20] Batch [586/938] Loss: 0.5658 | Acc: 81.76%
# Train Epoch [3/20] Batch [587/938] Loss: 0.4614 | Acc: 81.77%
# Train Epoch [3/20] Batch [588/938] Loss: 0.4452 | Acc: 81.78%
# Train Epoch [3/20] Batch [589/938] Loss: 0.3722 | Acc: 81.79%
# Train Epoch [3/20] Batch [590/938] Loss: 0.3628 | Acc: 81.79%
# Train Epoch [3/20] Batch [591/938] Loss: 0.3932 | Acc: 81.79%
# Train Epoch [3/20] Batch [592/938] Loss: 0.6153 | Acc: 81.79%
# Train Epoch [3/20] Batch [593/938] Loss: 0.4013 | Acc: 81.80%
# Train Epoch [3/20] Batch [594/938] Loss: 0.3590 | Acc: 81.81%
# Train Epoch [3/20] Batch [595/938] Loss: 0.4118 | Acc: 81.81%
# Train Epoch [3/20] Batch [596/938] Loss: 0.3189 | Acc: 81.83%
# Train Epoch [3/20] Batch [597/938] Loss: 0.5689 | Acc: 81.83%
# Train Epoch [3/20] Batch [598/938] Loss: 0.3288 | Acc: 81.85%
# Train Epoch [3/20] Batch [599/938] Loss: 0.6197 | Acc: 81.83%
# Train Epoch [3/20] Batch [600/938] Loss: 0.5024 | Acc: 81.84%
# Train Epoch [3/20] Batch [601/938] Loss: 0.8338 | Acc: 81.83%
# Train Epoch [3/20] Batch [602/938] Loss: 0.4655 | Acc: 81.84%
# Train Epoch [3/20] Batch [603/938] Loss: 0.3601 | Acc: 81.84%
# Train Epoch [3/20] Batch [604/938] Loss: 0.4614 | Acc: 81.84%
# Train Epoch [3/20] Batch [605/938] Loss: 0.5662 | Acc: 81.85%
# Train Epoch [3/20] Batch [606/938] Loss: 0.3116 | Acc: 81.86%
# Train Epoch [3/20] Batch [607/938] Loss: 0.4233 | Acc: 81.87%
# Train Epoch [3/20] Batch [608/938] Loss: 0.5257 | Acc: 81.86%
# Train Epoch [3/20] Batch [609/938] Loss: 0.6093 | Acc: 81.86%
# Train Epoch [3/20] Batch [610/938] Loss: 0.3182 | Acc: 81.88%
# Train Epoch [3/20] Batch [611/938] Loss: 0.3431 | Acc: 81.89%
# Train Epoch [3/20] Batch [612/938] Loss: 0.4528 | Acc: 81.89%
# Train Epoch [3/20] Batch [613/938] Loss: 0.4505 | Acc: 81.89%
# Train Epoch [3/20] Batch [614/938] Loss: 0.5471 | Acc: 81.88%
# Train Epoch [3/20] Batch [615/938] Loss: 0.3401 | Acc: 81.90%
# Train Epoch [3/20] Batch [616/938] Loss: 0.5679 | Acc: 81.90%
# Train Epoch [3/20] Batch [617/938] Loss: 0.3934 | Acc: 81.91%
# Train Epoch [3/20] Batch [618/938] Loss: 0.6283 | Acc: 81.89%
# Train Epoch [3/20] Batch [619/938] Loss: 0.3388 | Acc: 81.91%
# Train Epoch [3/20] Batch [620/938] Loss: 0.6676 | Acc: 81.90%
# Train Epoch [3/20] Batch [621/938] Loss: 0.6455 | Acc: 81.89%
# Train Epoch [3/20] Batch [622/938] Loss: 0.5748 | Acc: 81.90%
# Train Epoch [3/20] Batch [623/938] Loss: 0.6140 | Acc: 81.89%
# Train Epoch [3/20] Batch [624/938] Loss: 0.6094 | Acc: 81.89%
# Train Epoch [3/20] Batch [625/938] Loss: 0.5195 | Acc: 81.89%
# Train Epoch [3/20] Batch [626/938] Loss: 0.4143 | Acc: 81.90%
# Train Epoch [3/20] Batch [627/938] Loss: 0.5681 | Acc: 81.89%
# Train Epoch [3/20] Batch [628/938] Loss: 0.5870 | Acc: 81.89%
# Train Epoch [3/20] Batch [629/938] Loss: 0.5145 | Acc: 81.89%
# Train Epoch [3/20] Batch [630/938] Loss: 0.7429 | Acc: 81.88%
# Train Epoch [3/20] Batch [631/938] Loss: 0.5615 | Acc: 81.88%
# Train Epoch [3/20] Batch [632/938] Loss: 0.6677 | Acc: 81.88%
# Train Epoch [3/20] Batch [633/938] Loss: 0.5358 | Acc: 81.87%
# Train Epoch [3/20] Batch [634/938] Loss: 0.5598 | Acc: 81.87%
# Train Epoch [3/20] Batch [635/938] Loss: 0.3589 | Acc: 81.87%
# Train Epoch [3/20] Batch [636/938] Loss: 0.4541 | Acc: 81.87%
# Train Epoch [3/20] Batch [637/938] Loss: 0.7353 | Acc: 81.86%
# Train Epoch [3/20] Batch [638/938] Loss: 0.3373 | Acc: 81.87%
# Train Epoch [3/20] Batch [639/938] Loss: 0.4456 | Acc: 81.88%
# Train Epoch [3/20] Batch [640/938] Loss: 0.6729 | Acc: 81.88%
# Train Epoch [3/20] Batch [641/938] Loss: 0.5122 | Acc: 81.88%
# Train Epoch [3/20] Batch [642/938] Loss: 0.4161 | Acc: 81.88%
# Train Epoch [3/20] Batch [643/938] Loss: 0.3887 | Acc: 81.89%
# Train Epoch [3/20] Batch [644/938] Loss: 0.3992 | Acc: 81.90%
# Train Epoch [3/20] Batch [645/938] Loss: 0.5311 | Acc: 81.89%
# Train Epoch [3/20] Batch [646/938] Loss: 0.6191 | Acc: 81.89%
# Train Epoch [3/20] Batch [647/938] Loss: 0.6911 | Acc: 81.88%
# Train Epoch [3/20] Batch [648/938] Loss: 0.7276 | Acc: 81.87%
# Train Epoch [3/20] Batch [649/938] Loss: 0.4152 | Acc: 81.89%
# Train Epoch [3/20] Batch [650/938] Loss: 0.3567 | Acc: 81.89%
# Train Epoch [3/20] Batch [651/938] Loss: 0.5648 | Acc: 81.89%
# Train Epoch [3/20] Batch [652/938] Loss: 0.3657 | Acc: 81.90%
# Train Epoch [3/20] Batch [653/938] Loss: 0.3837 | Acc: 81.91%
# Train Epoch [3/20] Batch [654/938] Loss: 0.4003 | Acc: 81.92%
# Train Epoch [3/20] Batch [655/938] Loss: 0.3725 | Acc: 81.93%
# Train Epoch [3/20] Batch [656/938] Loss: 0.5749 | Acc: 81.93%
# Train Epoch [3/20] Batch [657/938] Loss: 0.5586 | Acc: 81.93%
# Train Epoch [3/20] Batch [658/938] Loss: 0.4665 | Acc: 81.93%
# Train Epoch [3/20] Batch [659/938] Loss: 0.4431 | Acc: 81.95%
# Train Epoch [3/20] Batch [660/938] Loss: 0.5323 | Acc: 81.95%
# Train Epoch [3/20] Batch [661/938] Loss: 0.5521 | Acc: 81.94%
# Train Epoch [3/20] Batch [662/938] Loss: 0.3458 | Acc: 81.95%
# Train Epoch [3/20] Batch [663/938] Loss: 0.2555 | Acc: 81.97%
# Train Epoch [3/20] Batch [664/938] Loss: 0.4447 | Acc: 81.97%
# Train Epoch [3/20] Batch [665/938] Loss: 0.4473 | Acc: 81.97%
# Train Epoch [3/20] Batch [666/938] Loss: 0.4405 | Acc: 81.97%
# Train Epoch [3/20] Batch [667/938] Loss: 0.4090 | Acc: 81.98%
# Train Epoch [3/20] Batch [668/938] Loss: 0.6796 | Acc: 81.98%
# Train Epoch [3/20] Batch [669/938] Loss: 0.3696 | Acc: 81.99%
# Train Epoch [3/20] Batch [670/938] Loss: 0.3803 | Acc: 82.00%
# Train Epoch [3/20] Batch [671/938] Loss: 0.3987 | Acc: 82.01%
# Train Epoch [3/20] Batch [672/938] Loss: 0.5067 | Acc: 82.01%
# Train Epoch [3/20] Batch [673/938] Loss: 0.6724 | Acc: 82.01%
# Train Epoch [3/20] Batch [674/938] Loss: 0.5664 | Acc: 82.00%
# Train Epoch [3/20] Batch [675/938] Loss: 0.4383 | Acc: 82.00%
# Train Epoch [3/20] Batch [676/938] Loss: 0.4680 | Acc: 82.00%
# Train Epoch [3/20] Batch [677/938] Loss: 0.4035 | Acc: 82.01%
# Train Epoch [3/20] Batch [678/938] Loss: 0.7566 | Acc: 82.01%
# Train Epoch [3/20] Batch [679/938] Loss: 0.3105 | Acc: 82.02%
# Train Epoch [3/20] Batch [680/938] Loss: 0.3979 | Acc: 82.02%
# Train Epoch [3/20] Batch [681/938] Loss: 0.4324 | Acc: 82.03%
# Train Epoch [3/20] Batch [682/938] Loss: 0.5573 | Acc: 82.02%
# Train Epoch [3/20] Batch [683/938] Loss: 0.5259 | Acc: 82.02%
# Train Epoch [3/20] Batch [684/938] Loss: 0.5089 | Acc: 82.02%
# Train Epoch [3/20] Batch [685/938] Loss: 0.3715 | Acc: 82.03%
# Train Epoch [3/20] Batch [686/938] Loss: 0.5026 | Acc: 82.03%
# Train Epoch [3/20] Batch [687/938] Loss: 0.6442 | Acc: 82.03%
# Train Epoch [3/20] Batch [688/938] Loss: 0.3650 | Acc: 82.04%
# Train Epoch [3/20] Batch [689/938] Loss: 0.5526 | Acc: 82.05%
# Train Epoch [3/20] Batch [690/938] Loss: 0.3643 | Acc: 82.05%
# Train Epoch [3/20] Batch [691/938] Loss: 0.5386 | Acc: 82.05%
# Train Epoch [3/20] Batch [692/938] Loss: 0.6633 | Acc: 82.04%
# Train Epoch [3/20] Batch [693/938] Loss: 0.4385 | Acc: 82.04%
# Train Epoch [3/20] Batch [694/938] Loss: 0.5163 | Acc: 82.04%
# Train Epoch [3/20] Batch [695/938] Loss: 0.6278 | Acc: 82.04%
# Train Epoch [3/20] Batch [696/938] Loss: 0.5210 | Acc: 82.04%
# Train Epoch [3/20] Batch [697/938] Loss: 0.4853 | Acc: 82.05%
# Train Epoch [3/20] Batch [698/938] Loss: 0.5654 | Acc: 82.04%
# Train Epoch [3/20] Batch [699/938] Loss: 0.6562 | Acc: 82.04%
# Train Epoch [3/20] Batch [700/938] Loss: 0.4759 | Acc: 82.04%
# Train Epoch [3/20] Batch [701/938] Loss: 0.4053 | Acc: 82.04%
# Train Epoch [3/20] Batch [702/938] Loss: 0.5578 | Acc: 82.04%
# Train Epoch [3/20] Batch [703/938] Loss: 0.4714 | Acc: 82.03%
# Train Epoch [3/20] Batch [704/938] Loss: 0.3126 | Acc: 82.04%
# Train Epoch [3/20] Batch [705/938] Loss: 0.4916 | Acc: 82.05%
# Train Epoch [3/20] Batch [706/938] Loss: 0.6388 | Acc: 82.04%
# Train Epoch [3/20] Batch [707/938] Loss: 0.5648 | Acc: 82.03%
# Train Epoch [3/20] Batch [708/938] Loss: 0.3708 | Acc: 82.04%
# Train Epoch [3/20] Batch [709/938] Loss: 0.3542 | Acc: 82.05%
# Train Epoch [3/20] Batch [710/938] Loss: 0.4738 | Acc: 82.05%
# Train Epoch [3/20] Batch [711/938] Loss: 0.4996 | Acc: 82.05%
# Train Epoch [3/20] Batch [712/938] Loss: 0.4847 | Acc: 82.06%
# Train Epoch [3/20] Batch [713/938] Loss: 0.4346 | Acc: 82.06%
# Train Epoch [3/20] Batch [714/938] Loss: 0.6130 | Acc: 82.07%
# Train Epoch [3/20] Batch [715/938] Loss: 0.3539 | Acc: 82.08%
# Train Epoch [3/20] Batch [716/938] Loss: 0.3674 | Acc: 82.08%
# Train Epoch [3/20] Batch [717/938] Loss: 0.3372 | Acc: 82.09%
# Train Epoch [3/20] Batch [718/938] Loss: 0.5417 | Acc: 82.09%
# Train Epoch [3/20] Batch [719/938] Loss: 0.4042 | Acc: 82.10%
# Train Epoch [3/20] Batch [720/938] Loss: 0.4573 | Acc: 82.11%
# Train Epoch [3/20] Batch [721/938] Loss: 0.6545 | Acc: 82.10%
# Train Epoch [3/20] Batch [722/938] Loss: 0.4516 | Acc: 82.10%
# Train Epoch [3/20] Batch [723/938] Loss: 0.3197 | Acc: 82.12%
# Train Epoch [3/20] Batch [724/938] Loss: 0.4414 | Acc: 82.12%
# Train Epoch [3/20] Batch [725/938] Loss: 0.3867 | Acc: 82.12%
# Train Epoch [3/20] Batch [726/938] Loss: 0.5822 | Acc: 82.11%
# Train Epoch [3/20] Batch [727/938] Loss: 0.4872 | Acc: 82.11%
# Train Epoch [3/20] Batch [728/938] Loss: 0.5090 | Acc: 82.10%
# Train Epoch [3/20] Batch [729/938] Loss: 0.5218 | Acc: 82.10%
# Train Epoch [3/20] Batch [730/938] Loss: 0.3675 | Acc: 82.10%
# Train Epoch [3/20] Batch [731/938] Loss: 0.3615 | Acc: 82.10%
# Train Epoch [3/20] Batch [732/938] Loss: 0.6003 | Acc: 82.11%
# Train Epoch [3/20] Batch [733/938] Loss: 0.2567 | Acc: 82.12%
# Train Epoch [3/20] Batch [734/938] Loss: 0.4325 | Acc: 82.12%
# Train Epoch [3/20] Batch [735/938] Loss: 0.4519 | Acc: 82.11%
# Train Epoch [3/20] Batch [736/938] Loss: 0.5303 | Acc: 82.11%
# Train Epoch [3/20] Batch [737/938] Loss: 0.5462 | Acc: 82.10%
# Train Epoch [3/20] Batch [738/938] Loss: 0.4453 | Acc: 82.10%
# Train Epoch [3/20] Batch [739/938] Loss: 0.3602 | Acc: 82.11%
# Train Epoch [3/20] Batch [740/938] Loss: 0.5934 | Acc: 82.10%
# Train Epoch [3/20] Batch [741/938] Loss: 0.3817 | Acc: 82.11%
# Train Epoch [3/20] Batch [742/938] Loss: 0.5073 | Acc: 82.11%
# Train Epoch [3/20] Batch [743/938] Loss: 0.4996 | Acc: 82.11%
# Train Epoch [3/20] Batch [744/938] Loss: 0.2871 | Acc: 82.12%
# Train Epoch [3/20] Batch [745/938] Loss: 0.5162 | Acc: 82.13%
# Train Epoch [3/20] Batch [746/938] Loss: 0.4616 | Acc: 82.13%
# Train Epoch [3/20] Batch [747/938] Loss: 0.3113 | Acc: 82.13%
# Train Epoch [3/20] Batch [748/938] Loss: 0.3328 | Acc: 82.14%
# Train Epoch [3/20] Batch [749/938] Loss: 0.7064 | Acc: 82.13%
# Train Epoch [3/20] Batch [750/938] Loss: 0.5044 | Acc: 82.13%
# Train Epoch [3/20] Batch [751/938] Loss: 0.6076 | Acc: 82.13%
# Train Epoch [3/20] Batch [752/938] Loss: 0.4975 | Acc: 82.12%
# Train Epoch [3/20] Batch [753/938] Loss: 0.4804 | Acc: 82.13%
# Train Epoch [3/20] Batch [754/938] Loss: 0.4468 | Acc: 82.13%
# Train Epoch [3/20] Batch [755/938] Loss: 0.5803 | Acc: 82.13%
# Train Epoch [3/20] Batch [756/938] Loss: 0.6117 | Acc: 82.13%
# Train Epoch [3/20] Batch [757/938] Loss: 0.3188 | Acc: 82.13%
# Train Epoch [3/20] Batch [758/938] Loss: 0.5606 | Acc: 82.13%
# ...
# Train Epoch [20/20] Batch [688/938] Loss: 0.3144 | Acc: 93.69%
# Train Epoch [20/20] Batch [689/938] Loss: 0.1684 | Acc: 93.69%
# Train Epoch [20/20] Batch [690/938] Loss: 0.1696 | Acc: 93.69%
# Train Epoch [20/20] Batch [691/938] Loss: 0.1820 | Acc: 93.68%
# Train Epoch [20/20] Batch [692/938] Loss: 0.1595 | Acc: 93.68%
# Train Epoch [20/20] Batch [693/938] Loss: 0.1487 | Acc: 93.68%
# Train Epoch [20/20] Batch [694/938] Loss: 0.3848 | Acc: 93.67%
# Train Epoch [20/20] Batch [695/938] Loss: 0.2083 | Acc: 93.67%
# Train Epoch [20/20] Batch [696/938] Loss: 0.0945 | Acc: 93.68%
# Train Epoch [20/20] Batch [697/938] Loss: 0.1884 | Acc: 93.68%
# Train Epoch [20/20] Batch [698/938] Loss: 0.1721 | Acc: 93.68%
# Train Epoch [20/20] Batch [699/938] Loss: 0.2228 | Acc: 93.68%
# Train Epoch [20/20] Batch [700/938] Loss: 0.2555 | Acc: 93.67%
# Train Epoch [20/20] Batch [701/938] Loss: 0.1821 | Acc: 93.68%
# Train Epoch [20/20] Batch [702/938] Loss: 0.1265 | Acc: 93.68%
# Train Epoch [20/20] Batch [703/938] Loss: 0.1407 | Acc: 93.69%
# Train Epoch [20/20] Batch [704/938] Loss: 0.2938 | Acc: 93.68%
# Train Epoch [20/20] Batch [705/938] Loss: 0.1287 | Acc: 93.69%
# Train Epoch [20/20] Batch [706/938] Loss: 0.0877 | Acc: 93.69%
# Train Epoch [20/20] Batch [707/938] Loss: 0.3047 | Acc: 93.69%
# Train Epoch [20/20] Batch [708/938] Loss: 0.1902 | Acc: 93.69%
# Train Epoch [20/20] Batch [709/938] Loss: 0.1274 | Acc: 93.69%
# Train Epoch [20/20] Batch [710/938] Loss: 0.2999 | Acc: 93.69%
# Train Epoch [20/20] Batch [711/938] Loss: 0.2133 | Acc: 93.69%
# Train Epoch [20/20] Batch [712/938] Loss: 0.2513 | Acc: 93.68%
# Train Epoch [20/20] Batch [713/938] Loss: 0.1446 | Acc: 93.68%
# Train Epoch [20/20] Batch [714/938] Loss: 0.2608 | Acc: 93.68%
# Train Epoch [20/20] Batch [715/938] Loss: 0.2485 | Acc: 93.67%
# Train Epoch [20/20] Batch [716/938] Loss: 0.1037 | Acc: 93.68%
# Train Epoch [20/20] Batch [717/938] Loss: 0.2575 | Acc: 93.67%
# Train Epoch [20/20] Batch [718/938] Loss: 0.0774 | Acc: 93.67%
# Train Epoch [20/20] Batch [719/938] Loss: 0.1904 | Acc: 93.68%
# Train Epoch [20/20] Batch [720/938] Loss: 0.2277 | Acc: 93.68%
# Train Epoch [20/20] Batch [721/938] Loss: 0.1678 | Acc: 93.67%
# Train Epoch [20/20] Batch [722/938] Loss: 0.2109 | Acc: 93.67%
# Train Epoch [20/20] Batch [723/938] Loss: 0.3512 | Acc: 93.66%
# Train Epoch [20/20] Batch [724/938] Loss: 0.3331 | Acc: 93.65%
# Train Epoch [20/20] Batch [725/938] Loss: 0.1529 | Acc: 93.65%
# Train Epoch [20/20] Batch [726/938] Loss: 0.1685 | Acc: 93.66%
# Train Epoch [20/20] Batch [727/938] Loss: 0.2348 | Acc: 93.65%
# Train Epoch [20/20] Batch [728/938] Loss: 0.1540 | Acc: 93.66%
# Train Epoch [20/20] Batch [729/938] Loss: 0.2270 | Acc: 93.65%
# Train Epoch [20/20] Batch [730/938] Loss: 0.2658 | Acc: 93.65%
# Train Epoch [20/20] Batch [731/938] Loss: 0.2055 | Acc: 93.65%
# Train Epoch [20/20] Batch [732/938] Loss: 0.1088 | Acc: 93.65%
# Train Epoch [20/20] Batch [733/938] Loss: 0.1075 | Acc: 93.65%
# Train Epoch [20/20] Batch [734/938] Loss: 0.1894 | Acc: 93.66%
# Train Epoch [20/20] Batch [735/938] Loss: 0.2071 | Acc: 93.65%
# Train Epoch [20/20] Batch [736/938] Loss: 0.0989 | Acc: 93.66%
# Train Epoch [20/20] Batch [737/938] Loss: 0.3239 | Acc: 93.65%
# Train Epoch [20/20] Batch [738/938] Loss: 0.1541 | Acc: 93.66%
# Train Epoch [20/20] Batch [739/938] Loss: 0.2100 | Acc: 93.65%
# Train Epoch [20/20] Batch [740/938] Loss: 0.1606 | Acc: 93.65%
# Train Epoch [20/20] Batch [741/938] Loss: 0.1703 | Acc: 93.66%
# Train Epoch [20/20] Batch [742/938] Loss: 0.2258 | Acc: 93.65%
# Train Epoch [20/20] Batch [743/938] Loss: 0.1856 | Acc: 93.65%
# Train Epoch [20/20] Batch [744/938] Loss: 0.3345 | Acc: 93.64%
# Train Epoch [20/20] Batch [745/938] Loss: 0.2154 | Acc: 93.64%
# Train Epoch [20/20] Batch [746/938] Loss: 0.2725 | Acc: 93.64%
# Train Epoch [20/20] Batch [747/938] Loss: 0.2744 | Acc: 93.63%
# Train Epoch [20/20] Batch [748/938] Loss: 0.2447 | Acc: 93.63%
# Train Epoch [20/20] Batch [749/938] Loss: 0.1915 | Acc: 93.63%
# Train Epoch [20/20] Batch [750/938] Loss: 0.2234 | Acc: 93.62%
# Train Epoch [20/20] Batch [751/938] Loss: 0.0769 | Acc: 93.63%
# Train Epoch [20/20] Batch [752/938] Loss: 0.1540 | Acc: 93.63%
# Train Epoch [20/20] Batch [753/938] Loss: 0.1984 | Acc: 93.63%
# Train Epoch [20/20] Batch [754/938] Loss: 0.2442 | Acc: 93.63%
# Train Epoch [20/20] Batch [755/938] Loss: 0.0998 | Acc: 93.63%
# Train Epoch [20/20] Batch [756/938] Loss: 0.1408 | Acc: 93.63%
# Train Epoch [20/20] Batch [757/938] Loss: 0.1207 | Acc: 93.64%
# Train Epoch [20/20] Batch [758/938] Loss: 0.0740 | Acc: 93.64%
# Train Epoch [20/20] Batch [759/938] Loss: 0.1721 | Acc: 93.65%
# Train Epoch [20/20] Batch [760/938] Loss: 0.1868 | Acc: 93.64%
# Train Epoch [20/20] Batch [761/938] Loss: 0.2436 | Acc: 93.64%
# Train Epoch [20/20] Batch [762/938] Loss: 0.2960 | Acc: 93.64%
# Train Epoch [20/20] Batch [763/938] Loss: 0.2002 | Acc: 93.64%
# Train Epoch [20/20] Batch [764/938] Loss: 0.1906 | Acc: 93.64%
# Train Epoch [20/20] Batch [765/938] Loss: 0.2174 | Acc: 93.64%
# Train Epoch [20/20] Batch [766/938] Loss: 0.1222 | Acc: 93.64%
# Train Epoch [20/20] Batch [767/938] Loss: 0.1727 | Acc: 93.64%
# Train Epoch [20/20] Batch [768/938] Loss: 0.1473 | Acc: 93.64%
# Train Epoch [20/20] Batch [769/938] Loss: 0.2860 | Acc: 93.64%
# Train Epoch [20/20] Batch [770/938] Loss: 0.2136 | Acc: 93.64%
# Train Epoch [20/20] Batch [771/938] Loss: 0.0485 | Acc: 93.65%
# Train Epoch [20/20] Batch [772/938] Loss: 0.1730 | Acc: 93.65%
# Train Epoch [20/20] Batch [773/938] Loss: 0.1092 | Acc: 93.65%
# Train Epoch [20/20] Batch [774/938] Loss: 0.2037 | Acc: 93.65%
# Train Epoch [20/20] Batch [775/938] Loss: 0.1168 | Acc: 93.66%
# Train Epoch [20/20] Batch [776/938] Loss: 0.2270 | Acc: 93.65%
# Train Epoch [20/20] Batch [777/938] Loss: 0.2428 | Acc: 93.65%
# Train Epoch [20/20] Batch [778/938] Loss: 0.1728 | Acc: 93.64%
# Train Epoch [20/20] Batch [779/938] Loss: 0.0760 | Acc: 93.65%
# Train Epoch [20/20] Batch [780/938] Loss: 0.2692 | Acc: 93.65%
# Train Epoch [20/20] Batch [781/938] Loss: 0.1593 | Acc: 93.65%
# Train Epoch [20/20] Batch [782/938] Loss: 0.1570 | Acc: 93.65%
# Train Epoch [20/20] Batch [783/938] Loss: 0.1621 | Acc: 93.65%
# Train Epoch [20/20] Batch [784/938] Loss: 0.0763 | Acc: 93.65%
# Train Epoch [20/20] Batch [785/938] Loss: 0.2829 | Acc: 93.65%
# Train Epoch [20/20] Batch [786/938] Loss: 0.1946 | Acc: 93.64%
# Train Epoch [20/20] Batch [787/938] Loss: 0.3863 | Acc: 93.64%
# Train Epoch [20/20] Batch [788/938] Loss: 0.2176 | Acc: 93.64%
# Train Epoch [20/20] Batch [789/938] Loss: 0.3319 | Acc: 93.63%
# Train Epoch [20/20] Batch [790/938] Loss: 0.1498 | Acc: 93.64%
# Train Epoch [20/20] Batch [791/938] Loss: 0.1965 | Acc: 93.64%
# Train Epoch [20/20] Batch [792/938] Loss: 0.4121 | Acc: 93.63%
# Train Epoch [20/20] Batch [793/938] Loss: 0.0817 | Acc: 93.63%
# Train Epoch [20/20] Batch [794/938] Loss: 0.0968 | Acc: 93.63%
# Train Epoch [20/20] Batch [795/938] Loss: 0.2468 | Acc: 93.63%
# Train Epoch [20/20] Batch [796/938] Loss: 0.2185 | Acc: 93.63%
# Train Epoch [20/20] Batch [797/938] Loss: 0.0819 | Acc: 93.64%
# Train Epoch [20/20] Batch [798/938] Loss: 0.2904 | Acc: 93.63%
# Train Epoch [20/20] Batch [799/938] Loss: 0.1919 | Acc: 93.63%
# Train Epoch [20/20] Batch [800/938] Loss: 0.2465 | Acc: 93.63%
# Train Epoch [20/20] Batch [801/938] Loss: 0.1147 | Acc: 93.64%
# Train Epoch [20/20] Batch [802/938] Loss: 0.1154 | Acc: 93.64%
# Train Epoch [20/20] Batch [803/938] Loss: 0.2617 | Acc: 93.64%
# Train Epoch [20/20] Batch [804/938] Loss: 0.2396 | Acc: 93.63%
# Train Epoch [20/20] Batch [805/938] Loss: 0.1660 | Acc: 93.64%
# Train Epoch [20/20] Batch [806/938] Loss: 0.1121 | Acc: 93.64%
# Train Epoch [20/20] Batch [807/938] Loss: 0.2346 | Acc: 93.63%
# Train Epoch [20/20] Batch [808/938] Loss: 0.2671 | Acc: 93.63%
# Train Epoch [20/20] Batch [809/938] Loss: 0.1784 | Acc: 93.64%
# Train Epoch [20/20] Batch [810/938] Loss: 0.3626 | Acc: 93.62%
# Train Epoch [20/20] Batch [811/938] Loss: 0.0702 | Acc: 93.63%
# Train Epoch [20/20] Batch [812/938] Loss: 0.0661 | Acc: 93.64%
# Train Epoch [20/20] Batch [813/938] Loss: 0.2372 | Acc: 93.63%
# Train Epoch [20/20] Batch [814/938] Loss: 0.2711 | Acc: 93.63%
# Train Epoch [20/20] Batch [815/938] Loss: 0.1683 | Acc: 93.63%
# Train Epoch [20/20] Batch [816/938] Loss: 0.1962 | Acc: 93.63%
# Train Epoch [20/20] Batch [817/938] Loss: 0.2213 | Acc: 93.62%
# Train Epoch [20/20] Batch [818/938] Loss: 0.0584 | Acc: 93.63%
# Train Epoch [20/20] Batch [819/938] Loss: 0.2950 | Acc: 93.62%
# Train Epoch [20/20] Batch [820/938] Loss: 0.1619 | Acc: 93.62%
# Train Epoch [20/20] Batch [821/938] Loss: 0.2375 | Acc: 93.62%
# Train Epoch [20/20] Batch [822/938] Loss: 0.2116 | Acc: 93.62%
# Train Epoch [20/20] Batch [823/938] Loss: 0.2085 | Acc: 93.62%
# Train Epoch [20/20] Batch [824/938] Loss: 0.1691 | Acc: 93.62%
# Train Epoch [20/20] Batch [825/938] Loss: 0.2359 | Acc: 93.62%
# Train Epoch [20/20] Batch [826/938] Loss: 0.1280 | Acc: 93.62%
# Train Epoch [20/20] Batch [827/938] Loss: 0.1832 | Acc: 93.62%
# Train Epoch [20/20] Batch [828/938] Loss: 0.2187 | Acc: 93.62%
# Train Epoch [20/20] Batch [829/938] Loss: 0.1332 | Acc: 93.62%
# Train Epoch [20/20] Batch [830/938] Loss: 0.3101 | Acc: 93.62%
# Train Epoch [20/20] Batch [831/938] Loss: 0.2174 | Acc: 93.62%
# Train Epoch [20/20] Batch [832/938] Loss: 0.1729 | Acc: 93.62%
# Train Epoch [20/20] Batch [833/938] Loss: 0.1141 | Acc: 93.62%
# Train Epoch [20/20] Batch [834/938] Loss: 0.0676 | Acc: 93.63%
# Train Epoch [20/20] Batch [835/938] Loss: 0.1363 | Acc: 93.63%
# Train Epoch [20/20] Batch [836/938] Loss: 0.1517 | Acc: 93.63%
# Train Epoch [20/20] Batch [837/938] Loss: 0.2797 | Acc: 93.63%
# Train Epoch [20/20] Batch [838/938] Loss: 0.1587 | Acc: 93.62%
# Train Epoch [20/20] Batch [839/938] Loss: 0.3304 | Acc: 93.62%
# Train Epoch [20/20] Batch [840/938] Loss: 0.0830 | Acc: 93.62%
# Train Epoch [20/20] Batch [841/938] Loss: 0.3435 | Acc: 93.62%
# Train Epoch [20/20] Batch [842/938] Loss: 0.2414 | Acc: 93.62%
# Train Epoch [20/20] Batch [843/938] Loss: 0.2647 | Acc: 93.61%
# Train Epoch [20/20] Batch [844/938] Loss: 0.2568 | Acc: 93.61%
# Train Epoch [20/20] Batch [845/938] Loss: 0.4160 | Acc: 93.60%
# Train Epoch [20/20] Batch [846/938] Loss: 0.2085 | Acc: 93.60%
# Train Epoch [20/20] Batch [847/938] Loss: 0.2353 | Acc: 93.60%
# Train Epoch [20/20] Batch [848/938] Loss: 0.2916 | Acc: 93.60%
# Train Epoch [20/20] Batch [849/938] Loss: 0.1903 | Acc: 93.60%
# Train Epoch [20/20] Batch [850/938] Loss: 0.2659 | Acc: 93.59%
# Train Epoch [20/20] Batch [851/938] Loss: 0.1946 | Acc: 93.59%
# Train Epoch [20/20] Batch [852/938] Loss: 0.1315 | Acc: 93.59%
# Train Epoch [20/20] Batch [853/938] Loss: 0.1414 | Acc: 93.59%
# Train Epoch [20/20] Batch [854/938] Loss: 0.1250 | Acc: 93.60%
# Train Epoch [20/20] Batch [855/938] Loss: 0.1431 | Acc: 93.60%
# Train Epoch [20/20] Batch [856/938] Loss: 0.1188 | Acc: 93.60%
# Train Epoch [20/20] Batch [857/938] Loss: 0.2176 | Acc: 93.60%
# Train Epoch [20/20] Batch [858/938] Loss: 0.3620 | Acc: 93.59%
# Train Epoch [20/20] Batch [859/938] Loss: 0.1178 | Acc: 93.60%
# Train Epoch [20/20] Batch [860/938] Loss: 0.0887 | Acc: 93.60%
# Train Epoch [20/20] Batch [861/938] Loss: 0.2792 | Acc: 93.59%
# Train Epoch [20/20] Batch [862/938] Loss: 0.1094 | Acc: 93.60%
# Train Epoch [20/20] Batch [863/938] Loss: 0.2491 | Acc: 93.59%
# Train Epoch [20/20] Batch [864/938] Loss: 0.3968 | Acc: 93.59%
# Train Epoch [20/20] Batch [865/938] Loss: 0.2088 | Acc: 93.59%
# Train Epoch [20/20] Batch [866/938] Loss: 0.4171 | Acc: 93.58%
# Train Epoch [20/20] Batch [867/938] Loss: 0.1670 | Acc: 93.58%
# Train Epoch [20/20] Batch [868/938] Loss: 0.1457 | Acc: 93.58%
# Train Epoch [20/20] Batch [869/938] Loss: 0.1795 | Acc: 93.58%
# Train Epoch [20/20] Batch [870/938] Loss: 0.1285 | Acc: 93.58%
# Train Epoch [20/20] Batch [871/938] Loss: 0.1278 | Acc: 93.58%
# Train Epoch [20/20] Batch [872/938] Loss: 0.1781 | Acc: 93.59%
# Train Epoch [20/20] Batch [873/938] Loss: 0.1377 | Acc: 93.59%
# Train Epoch [20/20] Batch [874/938] Loss: 0.0823 | Acc: 93.59%
# Train Epoch [20/20] Batch [875/938] Loss: 0.2487 | Acc: 93.59%
# Train Epoch [20/20] Batch [876/938] Loss: 0.2764 | Acc: 93.59%
# Train Epoch [20/20] Batch [877/938] Loss: 0.1776 | Acc: 93.59%
# Train Epoch [20/20] Batch [878/938] Loss: 0.2813 | Acc: 93.59%
# Train Epoch [20/20] Batch [879/938] Loss: 0.2010 | Acc: 93.59%
# Train Epoch [20/20] Batch [880/938] Loss: 0.3505 | Acc: 93.58%
# Train Epoch [20/20] Batch [881/938] Loss: 0.1601 | Acc: 93.58%
# Train Epoch [20/20] Batch [882/938] Loss: 0.1944 | Acc: 93.58%
# Train Epoch [20/20] Batch [883/938] Loss: 0.1992 | Acc: 93.58%
# Train Epoch [20/20] Batch [884/938] Loss: 0.1488 | Acc: 93.58%
# Train Epoch [20/20] Batch [885/938] Loss: 0.2102 | Acc: 93.58%
# Train Epoch [20/20] Batch [886/938] Loss: 0.1282 | Acc: 93.58%
# Train Epoch [20/20] Batch [887/938] Loss: 0.2487 | Acc: 93.58%
# Train Epoch [20/20] Batch [888/938] Loss: 0.1564 | Acc: 93.58%
# Train Epoch [20/20] Batch [889/938] Loss: 0.1923 | Acc: 93.58%
# Train Epoch [20/20] Batch [890/938] Loss: 0.2414 | Acc: 93.58%
# Train Epoch [20/20] Batch [891/938] Loss: 0.0928 | Acc: 93.58%
# Train Epoch [20/20] Batch [892/938] Loss: 0.3280 | Acc: 93.58%
# Train Epoch [20/20] Batch [893/938] Loss: 0.1796 | Acc: 93.58%
# Train Epoch [20/20] Batch [894/938] Loss: 0.2038 | Acc: 93.58%
# Train Epoch [20/20] Batch [895/938] Loss: 0.2703 | Acc: 93.57%
# Train Epoch [20/20] Batch [896/938] Loss: 0.1356 | Acc: 93.57%
# Train Epoch [20/20] Batch [897/938] Loss: 0.1207 | Acc: 93.57%
# Train Epoch [20/20] Batch [898/938] Loss: 0.1113 | Acc: 93.57%
# Train Epoch [20/20] Batch [899/938] Loss: 0.1523 | Acc: 93.58%
# Train Epoch [20/20] Batch [900/938] Loss: 0.1254 | Acc: 93.58%
# Train Epoch [20/20] Batch [901/938] Loss: 0.0556 | Acc: 93.58%
# Train Epoch [20/20] Batch [902/938] Loss: 0.1203 | Acc: 93.58%
# Train Epoch [20/20] Batch [903/938] Loss: 0.1101 | Acc: 93.59%
# Train Epoch [20/20] Batch [904/938] Loss: 0.1732 | Acc: 93.58%
# Train Epoch [20/20] Batch [905/938] Loss: 0.1623 | Acc: 93.58%
# Train Epoch [20/20] Batch [906/938] Loss: 0.1957 | Acc: 93.58%
# Train Epoch [20/20] Batch [907/938] Loss: 0.2479 | Acc: 93.58%
# Train Epoch [20/20] Batch [908/938] Loss: 0.1645 | Acc: 93.58%
# Train Epoch [20/20] Batch [909/938] Loss: 0.2819 | Acc: 93.58%
# Train Epoch [20/20] Batch [910/938] Loss: 0.1030 | Acc: 93.58%
# Train Epoch [20/20] Batch [911/938] Loss: 0.3402 | Acc: 93.58%
# Train Epoch [20/20] Batch [912/938] Loss: 0.1418 | Acc: 93.58%
# Train Epoch [20/20] Batch [913/938] Loss: 0.2284 | Acc: 93.58%
# Train Epoch [20/20] Batch [914/938] Loss: 0.1238 | Acc: 93.58%
# Train Epoch [20/20] Batch [915/938] Loss: 0.0546 | Acc: 93.58%
# Train Epoch [20/20] Batch [916/938] Loss: 0.0908 | Acc: 93.59%
# Train Epoch [20/20] Batch [917/938] Loss: 0.1567 | Acc: 93.59%
# Train Epoch [20/20] Batch [918/938] Loss: 0.1317 | Acc: 93.59%
# Train Epoch [20/20] Batch [919/938] Loss: 0.1228 | Acc: 93.59%
# Train Epoch [20/20] Batch [920/938] Loss: 0.1961 | Acc: 93.58%
# Train Epoch [20/20] Batch [921/938] Loss: 0.1639 | Acc: 93.58%
# Train Epoch [20/20] Batch [922/938] Loss: 0.2673 | Acc: 93.58%
# Train Epoch [20/20] Batch [923/938] Loss: 0.1164 | Acc: 93.58%
# Train Epoch [20/20] Batch [924/938] Loss: 0.0580 | Acc: 93.59%
# Train Epoch [20/20] Batch [925/938] Loss: 0.2046 | Acc: 93.59%
# Train Epoch [20/20] Batch [926/938] Loss: 0.1581 | Acc: 93.59%
# Train Epoch [20/20] Batch [927/938] Loss: 0.3082 | Acc: 93.58%
# Train Epoch [20/20] Batch [928/938] Loss: 0.1231 | Acc: 93.58%
# Train Epoch [20/20] Batch [929/938] Loss: 0.1656 | Acc: 93.59%
# Train Epoch [20/20] Batch [930/938] Loss: 0.2057 | Acc: 93.59%
# Train Epoch [20/20] Batch [931/938] Loss: 0.1946 | Acc: 93.58%
# Train Epoch [20/20] Batch [932/938] Loss: 0.0832 | Acc: 93.59%
# Train Epoch [20/20] Batch [933/938] Loss: 0.0919 | Acc: 93.59%
# Train Epoch [20/20] Batch [934/938] Loss: 0.2140 | Acc: 93.59%
# Train Epoch [20/20] Batch [935/938] Loss: 0.1864 | Acc: 93.59%
# Train Epoch [20/20] Batch [936/938] Loss: 0.1708 | Acc: 93.59%
# Train Epoch [20/20] Batch [937/938] Loss: 0.0942 | Acc: 93.59%
# Train Epoch [20/20] Batch [938/938] Loss: 0.0577 | Acc: 93.59%
# Epoch 20 completed in 32.82s.
# Test Epoch [20/20] Loss: 0.1398 | Acc: 95.24% | Inference Time: 5.27s
# Saving best model...
# Epoch 20 results saved to CSV.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
file_path = 'Performer ReLu_lr_1e-3_dropout_0.3_bonus_MNIST.csv'
data = pd.read_csv(file_path)

# Extract data for plotting
epochs = data['Epoch']
train_times = data['Train Time (s)']
inference_times = data['Inference Time (s)']
accuracies = data['Accuracy (%)']

# Plot the data
plt.figure(figsize=(15, 5))

# Training time per epoch
plt.subplot(1, 3, 1)
plt.plot(epochs, train_times, marker='o', label='Train Time')
plt.xlabel("Epoch")
plt.ylabel("Time (s)")
plt.title("Training Time per Epoch")
plt.grid(True)
plt.legend()

# Inference time per epoch
plt.subplot(1, 3, 2)
plt.plot(epochs, inference_times, marker='o', color='orange', label='Inference Time')
plt.xlabel("Epoch")
plt.ylabel("Time (s)")
plt.title("Inference Time per Epoch")
plt.grid(True)
plt.legend()

# Test accuracy per epoch
plt.subplot(1, 3, 3)
plt.plot(epochs, accuracies, marker='o', color='green', label='Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.title("Test Accuracy per Epoch")
plt.grid(True)
plt.legend()

# Finalize and save the figure
plt.tight_layout()
output_path = "Performer ReLu_lr_1e-3_dropout_0.3_bonus_MNIST.png"
plt.savefig(output_path)
plt.show()

output_path
# Out:
# 'Performer ReLu_lr_1e-3_dropout_0.3_bonus_MNIST.png'
